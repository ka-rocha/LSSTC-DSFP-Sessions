# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib notebook

# %% [markdown]
# # Wranglin' –– Corraling Unruly Data
# One bit at a time
# =====
#
# **Version 0.2**
#
# By AA Miller
# 2022 July 19

# %% [markdown]
# For this exercise you will need a five different text files. They have been compiled into a tarball that you should [download](https://arch.library.northwestern.edu/downloads/8g84mm66j?locale=en) and unpack in the same directory as this notebook.

# %% [markdown]
# Webster's Dictionary$^\ast$ defines wrangler as:
#
# **wrangler** noun
#
# wran·gler | raŋ-g(ə-)lər
#
# (short for horse-wrangler, probably partial translation of Mexican Spanish caballerango groom): a ranch hand who takes care of the saddle horses broadly : cowboy

# %% [markdown]
# $^\ast$actually https://www.merriam-webster.com/dictionary/ - Webster's didn't define wrangler in the way I wanted

# %% [markdown]
# How then, as astronomers, are we all like cowhands?
#
# Data are often like horses in that: they all differ, rarely conform to a single standard set of behavior, and they love to eat hay.$^\dagger$

# %% [markdown]
# $^\dagger$I made that last one up.

# %% [markdown]
# Thus, in our efforts to better understand the Universe, we must often manipulate, coax, and, in some cases, force our data to "behave." This involves a variety of tasks, such as: gathering, cleaning, matching, restructuring, transforming, filtering, combining, merging, verifying, and fixing data.

# %% [markdown]
# Here is a brief and unfortunate truth, there isn't a single person in the entire world that would organize data in *exactly* the same way that you would.
#
# As a result, you may find that data that are useful to you are not organized in an optimal fashion for use in your workflow/software.
#
# Hence: the need to wrangle.

# %% [markdown]
# There is one important and significant way in which our lives as astronomers are much better than the average data scientist: even though our data are "worthless," virtually all of it is numbers.
#
# Furthermore, I contend that most astronomical data can easily be organized into a simple tabular structure.

# %% [markdown]
# Nevertheless, as you will see during the exercises, even with relatively simple, small numerical data sets there is a need for wrangling.
#
# And wrangling brings up a lot of issues...

# %% [markdown]
# Consider the following data set that contains the street names for my best friends from childhood:
#
#     ['Ewing', 'Isabella', 'Reese', 'Isabella',
#      'Thayer', 'Reese', 'Reese', 'Ewing', 'Reece']
#
# Do you notice anything interesting?

# %% [markdown]
# Either my hometown has a street named "Reese"  and a street named "Reece", or the last entry was input incorrectly.
#
# If the later is true, then we have to raise the question of: what should we do?

# %% [markdown]
# For this particular data set, it would be possible to create a verification procedure to test for similar errors.
#
# 1. Collect every street name in the city (from post office?)
# 2. Confirm every data entry has a counterpart.
#
# For any instances where this isn't the case, one could then intervene with a correction.

# %% [markdown]
# This particular verification catches this street name error, but it doesn't correct for the possibility that the person doing the data entry may have been reading addresses really quickly and the third "Reese" entry should have actually said "Lawndale."
#
# (verification is really hard)

# %% [markdown]
# Data provenance – a historical record of the data and its origins – is really really hard.

# %% [markdown]
# If you are making "corrections" to the data, then each and every one of those corrections should be reported (for databases this is called "logging"). Ideally, these reports would live with the data so others could understand how things have changed.
#
# If you did change "Reece" to "Reese", anyone working with the data should be able to confirm those changes.

# %% [markdown]
# Suppose now you wanted to use the same street name data set to estimate which street I lived on while growing up.
#
# One way to mathematically approach this problem would be to convert the streets in the data set to GPS coordinates, and then to perform a KDE of the PDF for the coordinates of where I lived.
#
# This too is a form of wrangling, because the data you have (street names) are not the data you need (coordinates).

# %% [markdown]
# Why harp on this?
#
# In practice, data scientists (including astronomers) spend an unreasonable amount of time manipulating and quality checking data (some indsutry experts estimate that up to 80% of their time is spent warnglin').
#
# Today, we will work through several examples that require wrangling, while, hopefully, building some strategies to minimize the amount of time you spend on these tasks in the future.

# %% [markdown]
# For completeness, I will mention that there is a famous canonical paper about [data wrangling](http://vis.stanford.edu/files/2011-Wrangler-CHI.pdf), which introduces the [`Wrangler`](http://vis.stanford.edu/wrangler/), a tool specifically designed to take heterogeneous (text) data, and provide a set of suggested operations/manipulations to  create a homogenous table amenable to standard statistical analysis.
#
# One extremely nice property of the `Wrangler` is that it records every operation performed on the data, ensuring high-fidelity reporting on the data provenance. We should do a better job of this in astronomy.

# %% [markdown]
# Today, we are going to focus on `python` solutions to some specific astronomical data sets.
#
# Hopefully you learn some tricks to make your work easier in the future.

# %% [markdown]
# ## Problem 0) An (Incomplete) Introduction to Pandas DataFrames

# %% [markdown]
# **Problem 0a**
#
# Read the SDSS data for Problem 4, stored in a csv file called `DSFP_SDSS_spec_train.csv`, into a `pandas` DataFrame called `sdss_spec`.

# %% [markdown]
# After yesterday spending a great deal of time describing the value of binary data storage, does the fact that I am now providing a (moderate) amount of data as a plain ascii file mean that I am a bad teacher...
#
# *probably*

# %%
sdss_spec = pd.read_csv("/Users/kylerocha/Private/data/dsfp_Session15_wrangling/DSFP_SDSS_spec_train.csv")
sdss_spec.head()
# Out:
#             specObjID         z type  psfMag_u  psfMag_g  psfMag_r  psfMag_i  \
# 0  299567742770505728  0.071414  ext  20.88291  19.23907  18.56170  18.09715
# 1  299568017178650624  0.071380  ext  20.88291  19.23907  18.56170  18.09715
# 2  299566643258877952  0.088173  ext  20.84844  18.96040  18.08027  17.62953
# 3  299569116690278400  0.088161  ext  20.84844  18.96040  18.08027  17.62953
# 4  299568292056557568  0.066539  ext  21.28256  19.61427  18.98529  18.52956
#
#    psfMag_z  modelMag_u  modelMag_g  ...  extinction_i  extinction_z  w1mpro  \
# 0  17.76469    19.62189    18.03702  ...      0.061267      0.045572  14.395
# 1  17.76469    19.62189    18.03702  ...      0.061267      0.045572  14.395
# 2  17.31857    20.18508    18.26120  ...      0.047582      0.035392  14.162
# 3  17.31857    20.18508    18.26120  ...      0.047582      0.035392  14.162
# 4  18.26322    20.18081    18.47435  ...      0.058709      0.043669  14.734
#
#    w1snr  w2mpro  w2snr  w3mpro  w3snr  w4mpro  w4snr
# 0   21.1  14.236   15.6  11.029    6.8   8.579   -0.9
# 1   21.1  14.236   15.6  11.029    6.8   8.579   -0.9
# 2   35.0  13.970   22.3  12.233    2.9   9.067   -0.3
# 3   35.0  13.970   22.3  12.233    2.9   9.067   -0.3
# 4   30.6  14.512   17.6  11.078    9.8   9.054    2.3
#
# [5 rows x 26 columns]

# %% [markdown]
# `pandas` provides many different methods for selecting columns from the DataFrame. Supposing you wanted `psfMag`, you could use any of the following:
#
#     sdss_spec['psfMag_g']
#     sdss_spec[['psfMag_r', 'psfMag_z']]
#     sdss_spec.psfMag_g
#
# (notice that selecting multiple columns requires a list within `[]`)

# %% [markdown]
# **Problem 0b**
#
# Plot a histogram of the `psfMag_g` - `modelMag_g` distribution for the data set (which requires a selection of those two columns).
#
# Do you notice anything interesting?
#
# *Hint* - you may want to use more than the default number of bins (=10).

# %%
mag_diff = sdss_spec['psfMag_g'].values - sdss_spec['modelMag_g'].values

plt.hist(mag_diff, histtype='step', bins=50)
plt.xlabel('mag_diff')
plt.ylabel('count')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'count')

# %% [markdown]
# `pandas` can also be used to aggregate the results of a search.
#
# **Problem 0c**
#
# How many extended sources (`type` = `ext`) have `modelMag_i` between 19 and 20? Use as few lines as possible.

# %%
np.sum( sdss_spec['type'][ np.logical_and(sdss_spec.modelMag_i >19,sdss_spec.modelMag_i < 20) ] == 'ext' )
# Out:
# 369

# %% [markdown]
# `pandas` also enables [`GROUP BY`](http://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html) operations, where the data are split based on some criterion, a function is then applied to the groups, and the results are then combined back into a data structure.

# %% [markdown]
# **Problem 0d**
#
# Group the data by their `type` and then report the minimum, median, and maximum redshift of each group. Can you immediately tell anything about these sources based on these results?
#
# *Hint* - just execute the cell below.

# %%
grouped = sdss_spec.groupby([sdss_spec.type])
print(grouped['z'].min())
print(grouped['z'].median())
print(grouped['z'].max())
# Out:
# type
# ext   -0.005469
# ps    -0.010875
# Name: z, dtype: float64
# type
# ext    0.107352
# ps     0.000275
# Name: z, dtype: float64
# type
# ext    6.839257
# ps     6.687022
# Name: z, dtype: float64

# %% [markdown]
# Finally, yesterday we only briefly discussed joining tables, but this is where relational databases really shine.
#
# For this example we only have a single table, so we will exclude any examples of a `pandas` join, but there is functionality to [join or merge](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html) dataframes in a fashion that is fully analogous to databases.

# %% [markdown]
# ## Problem 1) The Sins of Our Predecessors

# %% [markdown]
# If at any point in your career you need to access archival infrared data, you will likely need to retrieve that information from the [NASA IPAC InfraRed Science Archive](https://irsa.ipac.caltech.edu). IRSA houses the data for every major NASA IR mission, and several ground-based missions as well (e.g., 2MASS, IRTF). Whether you are sudying brown dwarfs, explosive transients, solar system objects, star-formation, galaxy evolution, Milky Way dust and the resulting extinction of extragalactic observations, or quasars (and much more) the IR plays a critical role.

# %% [markdown]
# Given the importance of IR observations, it stands to reason that IRSA would provide data in a simple to read format for modern machines, such as comma separated values or FITS binary tables...
#
# Right?...

# %% [markdown]
# **Right?...**

# %% [markdown]
# In fact, IRSA has created their own standard for storing data in a text file. The particulars of this format can be found in `irsa_catalog_WISE_iPTF14jg_search_results.tbl`, a file that is written in the standard IRSA format.

# %% [markdown]
# *shameless plug alert!* iPTF14jg is a [really strange star](https://arxiv.org/pdf/1901.10693.pdf) that exhibited a large outburst that we still don't totally understand. The associated data file includes [NEOWISE](https://neowise.ipac.caltech.edu/) observations of the mid-IR evolution of this outburst.

# %% [markdown]
# **Problem 1a**
#
# Using `pandas` read the data in the IRSA table file into a `DataFrame` object.
#
# *Hint 1* - you absolutely should look at the text file to develop a strategy to accomplish this goal.
#
# *Hint 2* - you may want to manipulate the text file so that it can more easily be read by `pandas`. **If you do this** be sure to copy the file to another name as you will want to leave the original intact.

# %%
cat /Users/kylerocha/Private/data/dsfp_Session15_wrangling/irsa_catalog_WISE_iPTF14jg_search_results.tbl
# Out:
# \fixlen = T
# \RowsRetrieved = 137
# \ORIGIN = 'IPAC Infrared Science Archive (IRSA), Caltech/JPL'
# \DATETIME = '2019-03-21 09:05:51'
# \DataTag = 'ADS/IRSA.Gator#2019/0321/090551_4032'
# \DATABASE = 'NEOWISE-R Single Exposure (L1b) Source Table (neowiser_p1bs_psd)'
# \EQUINOX = 'J2000'
# \SKYAREA = 'within 2 arcsec of  ra=40.12558 dec=+60.87931 Eq J2000 '
# \StatusFile = '/workspace/TMP_SOmSjA_2912/Gator/irsa/4032/log.4032.html'
# \SQL = 'WHERE (no constraints)
# \SQL = 'SELECT (37 column names follow in next row.)'
# \
# \
# \ ra (deg)
# \ ___ right ascension (J2000)
# \ dec (deg)
# \ ___ declination (J2000)
# \ sigra (arcsec)
# \ ___ uncertainty in RA
# \ sigdec (arcsec)
# \ ___ uncertainty in DEC
# \ sigradec (arcsec)
# \ ___ uncertainty cross-term
# \ w1mpro (mag)
# \ ___ instrumental profile-fit photometry magnitude, band 1
# \ w1sigmpro (mag)
# \ ___ instrumental profile-fit photometry flux uncertainty in mag units, band 1
# \ w1snr
# \ ___ instrumental profile-fit photometry S/N ratio, band 1
# \ w1rchi2
# \ ___ instrumental profile-fit photometry reduced chi^2, band 1
# \ w2mpro (mag)
# \ ___ instrumental profile-fit photometry magnitude, band 2
# \ w2sigmpro (mag)
# \ ___ instrumental profile-fit photometry flux uncertainty in mag units, band 2
# \ w2snr
# \ ___ instrumental profile-fit photometry S/N ratio, band 2
# \ w2rchi2
# \ ___ instrumental profile-fit photometry reduced chi^2, band 2
# \ nb
# \ ___ number of blend components used in each fit
# \ na
# \ ___ active deblend flag (=1 if actively deblended)
# \ cc_flags
# \ ___ prioritized artifacts affecting the source in each band
# \ ph_qual
# \ ___ photometric quality of each band (A=highest, U=upper limit)
# \ qual_frame
# \ ___ quality score value for frame
# \ mjd (mjdate)
# \ ___ modified Julian date of the mid-point of the observation of the frame
# \ allwise_cntr
# \ ___ closest associated ALLWISE Catalog source cntr
# \ w1mpro_allwise (mag)
# \ ___ W1mpro magnitude  of the associated ALLWISE source
# \ w1sigmpro_allwise (mag)
# \ ___ W1 photometric uncertainty of the associated ALLWISE  source
# \ w2mpro_allwise (mag)
# \ ___ W2mpro magnitude  of the associated ALLWISE  source
# \ w2sigmpro_allwise (mag)
# \ ___ W2 photometric uncertainty of the associated ALLWISE  source
# \ w3mpro_allwise (mag)
# \ ___ W3mpro magnitude  of the associated ALLWISE  source
# \ w3sigmpro_allwise (mag)
# \ ___ W3 photometric uncertainty of the associated ALLWISE source
# \ w4mpro_allwise (mag)
# \ ___ W4mpro magnitude  of the associated ALLWISE  source
# \ w4sigmpro_allwise (mag)
# \ ___ W4 photometric uncertainty of the associated ALLWISE  source
# \ tmass_key
# \ ___ closest associated 2MASS All-Sky Release PSC key
# \ j_m_2mass (mag)
# \ ___ J magnitude entry of the associated 2MASS All-Sky PSC source
# \ j_msig_2mass (mag)
# \ ___ J photometric uncertainty of the associated 2MASS All-Sky PSC source
# \ h_m_2mass (mag)
# \ ___ H magnitude entry of the associated 2MASS All-Sky PSC source
# \ h_msig_2mass (mag)
# \ ___ H photometric uncertainty of the associated 2MASS All-Sky PSC source
# \ k_m_2mass (mag)
# \ ___ Ks magnitude entry of the associated 2MASS All-Sky PSC source
# \ k_msig_2mass (mag)
# \ ___ Ks photometric uncertainty of the associated 2MASS All-Sky PSC source
# \ dist (arcsec)
# \ ___ Distance between the target position and each source in arcsec.
# \ angle (deg)
# \ ___ Position Angle in degree.
# \
# \
# |ra        |dec       |sigra |sigdec|sigradec|w1mpro|w1sigmpro|w1snr |w1rchi2  |w2mpro|w2sigmpro|w2snr |w2rchi2  |nb  |na  |cc_flags|ph_qual|qual_frame|mjd           |allwise_cntr|w1mpro_allwise|w1sigmpro_allwise|w2mpro_allwise|w2sigmpro_allwise|w3mpro_allwise|w3sigmpro_allwise|w4mpro_allwise|w4sigmpro_allwise|tmass_key|j_m_2mass|j_msig_2mass|h_m_2mass|h_msig_2mass|k_m_2mass|k_msig_2mass|dist    |angle     |
# |double    |double    |double|double|double  |double|double   |double|double   |double|double   |double|double   |int |int |char    |char   |int       |double        |long        |double        |double           |double        |double           |double        |double           |double        |double           |int      |double   |double      |double   |double      |double   |double      |double  |double    |
# |deg       |deg       |arcsec|arcsec|arcsec  |mag   |mag      |      |         |mag   |mag      |      |         |    |    |        |       |          |mjdate        |            |mag           |mag              |mag           |mag              |mag           |mag              |mag           |mag              |         |mag      |mag         |mag      |mag         |mag      |mag         |arcsec  |deg       |
# |null      |null      |null  |null  |null    |null  |null     |null  |null     |null  |null     |null  |null     |null|null|null    |null   |null      |null          |null        |null          |null             |null          |null             |null          |null             |null          |null             |null     |null     |null        |null     |null        |null     |null        |null    |null      |
#  40.1255655 60.8793063 0.0947 0.0936  -0.0337 13.251     0.038   28.8 8.767e-01 12.735     0.058   18.6 7.135e-01    1    0 0000     AA              10 57621.23501414         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.028668 242.330013
#  40.1255740 60.8792970 0.0925 0.0874  -0.0397 13.241     0.036   30.0 1.261e+00 12.629     0.051   21.2 1.121e+00    1    0 0000     AA               5 57621.62810604         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.048011 192.659014
#  40.1256226 60.8793176 0.0808 0.0794   0.0098 12.753     0.039   27.8 7.640e-01 11.901     0.034   32.0 1.059e+00    1    0 0000     AA              10 57063.79830186         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.079498  69.867298
#  40.1255528 60.8792864 0.0663 0.0608  -0.0156 12.774     0.028   38.6 1.361e+00 11.935     0.037   29.3 7.133e-01    1    0 0000     AA              10 57256.77485551         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.097389 209.287467
#  40.1255725 60.8792803 0.0645 0.0599  -0.0223 12.840     0.028   38.7 1.555e+00 11.897     0.031   35.1 1.045e+00    1    0 0000     AA               5 57257.10275142         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.107707 187.006050
#  40.1255736 60.8792799 0.1164 0.1059  -0.0390 13.587     0.041   26.4 1.647e+00 13.145     0.076   14.3 1.030e+00    1    0 0000     AA               5 57987.97028435         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.108928 185.907602
#  40.1255644 60.8792744 0.0856 0.0860  -0.0310 13.198     0.035   31.2 1.725e+00 12.644     0.050   21.7 7.308e-01    1    0 0000     AA               5 57620.84192211         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.131052 192.038104
#  40.1255517 60.8792713 0.0679 0.0685  -0.0218 12.807     0.028   38.8 1.466e+00 11.989     0.038   28.3 7.736e-01    1    0 0000     AA              10 57256.64356978         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.147884 199.589209
#  40.1255718 60.8792687 0.1224 0.1104  -0.0547 13.496     0.044   24.6 9.767e-01 12.739     0.064   17.1 1.444e+00    1    0 0000     AA              10 57787.46478715         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.149378 185.518975
#  40.1256236 60.8792728 0.1107 0.0933  -0.0383 13.355     0.038   28.7 1.508e+00 12.658     0.055   19.7 6.638e-01    1    0 0000     AA               5 57621.16956245         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.154170 150.300579
#  40.1256406 60.8792778 0.0666 0.0631  -0.0228 12.774     0.027   39.6 1.482e+00 11.893     0.039   28.1 1.025e+00    1    0 0000     AA              10 57257.03717229         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.157204 137.514297
#  40.1255571 60.8792668 0.1325 0.1156  -0.0264 13.743     0.044   24.5 1.162e+00 13.081     0.072   15.1 7.188e-01    1    0 0000     AA               5 57988.29766973         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.160622 194.465237
#  40.1255835 60.8792651 0.1131 0.1036   0.0100 13.452     0.041   26.4 6.449e-01 12.819     0.066   16.5 7.711e-01    1    0 0000     AA               5 57790.34646045         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.161765 177.827528
#  40.1256055 60.8792645 0.1104 0.1036  -0.0323 13.337     0.044   24.9 1.626e+00 12.645     0.053   20.6 1.320e+00    1    0 0000     AA              10 57621.95561906         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.169772 164.744266
#  40.1255604 60.8792609 0.0691 0.0690  -0.0223 12.800     0.028   38.9 9.064e-01 12.008     0.038   28.5 5.125e-01    1    0 0000     AA              10 57423.32848997         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.180061 190.993589
#  40.1255550 60.8792608 0.0644 0.0651  -0.0135 12.726     0.029   37.8 1.324e+00 11.907     0.036   30.4 7.764e-01    1    0 0000     AA              10 57257.49635388         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.182458 193.889599
#  40.1255101 60.8792708 0.0697 0.0660  -0.0277 12.630     0.034   31.5 1.757e+00 11.688     0.034   32.1 9.085e-01    1    0 0000     AA              10 56895.39796988         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.186858 220.950772
#  40.1255283 60.8792640 0.0776 0.0845  -0.0188 12.690     0.032   33.7 1.320e+00 11.922     0.042   25.9 7.622e-01    1    0 0000     AA              10 57257.62751215         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.188744 208.676638
#  40.1254723 60.8792997 0.1111 0.0966  -0.0342 13.329     0.038   28.6 1.840e+00 12.554     0.054   20.0 7.196e-01    1    0 0000     AA               5 57621.30059315         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.192290 258.882033
#  40.1255899 60.8792563 0.1116 0.1096  -0.0214 13.379     0.050   21.9 1.027e+00 12.697     0.053   20.4 6.959e-01    1    0 g000     AA              10 57789.88791416         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.194099 174.873269
#  40.1255077 60.8792691 0.0579 0.0629  -0.0187 12.589     0.027   39.8 1.603e+00 11.772     0.038   28.4 9.415e-01    1    0 0000     AA              10 56895.13476218         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.194220 220.704324
#  40.1255092 60.8792662 0.0647 0.0608  -0.0256 12.650     0.028   38.5 1.129e+00 11.800     0.036   30.0 1.937e+00    1    0 0000     AA              10 56895.52951006         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.200609 218.190096
#  40.1254822 60.8792802 0.1274 0.1154  -0.0538 13.636     0.048   22.7 2.935e+00 13.109     0.076   14.4 5.164e-01    1    0 0000     AA               0 57988.49415192         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.202157 237.948411
#  40.1255581 60.8792536 0.1059 0.1107  -0.0361 13.382     0.039   27.7 1.306e+00 13.205     0.136    8.0 8.869e-01    1    0 0000     AB              10 57789.75701005         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.206640 190.700768
#  40.1255351 60.8792567 0.0687 0.0722  -0.0249 12.733     0.036   30.5 1.320e+00 11.965     0.034   32.1 7.977e-01    1    0 0000     AA              10 57257.16833060         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.207370 202.291479
#  40.1256052 60.8792527 0.0694 0.0674  -0.0116 12.774     0.031   35.2 1.900e+00 11.875     0.041   26.8 7.558e-01    1    0 0000     AA              10 57063.86400829         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.210961 167.919533
#  40.1255317 60.8792558 0.0602 0.0655  -0.0225 12.630     0.028   38.9 1.068e+00 11.699     0.037   29.4 1.011e+00    1    0 0000     AA              10 56895.72688403         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.212678 203.445257
#  40.1255142 60.8792603 0.0321 0.0289   0.0046 10.832     0.017   63.1 1.122e+00  9.974     0.016   66.0 1.224e+00    1    0 0000     AA              10 56704.33137932         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.212833 212.793665
#  40.1255508 60.8792513 0.0613 0.0560  -0.0197 12.642     0.025   42.7 9.910e-01 11.704     0.029   37.0 1.163e+00    1    0 0000     AA              10 56895.33213615         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.217422 193.608490
#  40.1254844 60.8792714 0.0831 0.0906  -0.0328 13.262     0.037   29.0 9.108e-01 12.569     0.061   17.7 1.001e+00    1    0 0000     AA              10 57621.69368505         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.217618 230.318160
#  40.1254766 60.8792760 0.0733 0.0643  -0.0119 12.808     0.027   40.1 1.001e+00 11.928     0.035   30.7 5.873e-01    1    0 0000     AA               5 57256.90601388         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.218635 235.953964
#  40.1256279 60.8792537 0.0744 0.0707  -0.0176 12.768     0.033   33.4 9.477e-01 11.919     0.034   31.5 7.105e-01    1    0 g000     AA              10 57063.33848389         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.219369 157.508341
#  40.1255406 60.8792519 0.0594 0.0548  -0.0186 12.560     0.025   43.6 1.026e+00 11.710     0.030   36.3 2.837e-01    1    0 0000     AA               5 56894.87168178         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.220250 198.263852
#  40.1255639 60.8792490 0.0347 0.0307   0.0018 10.829     0.018   61.9 5.829e+00 10.023     0.017   63.1 4.073e+00    1    0 0000     AA              10 56704.52888045         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.221405 187.319234
#  40.1255361 60.8792518 0.0323 0.0282  -0.0038 10.820     0.015   73.7 5.074e-01  9.954     0.017   62.4 1.008e+00    1    0 0000     AA              10 56704.72650891         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.223190 200.157141
#  40.1255708 60.8792479 0.0341 0.0319  -0.0117 10.824     0.018   59.4 3.124e+00 10.004     0.017   63.7 1.918e+00    1    0 0000     AA              10 56704.19958457         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.224140 184.123694
#  40.1255382 60.8792501 0.0636 0.0571  -0.0186 12.577     0.025   43.6 1.125e+00 11.717     0.033   33.2 6.118e-01    1    0 0000     AA              10 56895.20059593         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.227736 198.757493
#  40.1255170 60.8792536 0.0677 0.0586  -0.0197 12.742     0.031   35.3 1.621e+00 11.902     0.036   30.2 6.689e-01    1    0 0000     AA              10 57257.75879784         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.231092 208.528524
#  40.1255453 60.8792476 0.0764 0.0656  -0.0285 12.641     0.029   36.9 1.107e+00 11.729     0.042   25.9 7.550e-01    1    0 0000     AA              10 56895.85842431         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.232721 195.142792
#  40.1254806 60.8792657 0.0701 0.0712  -0.0313 12.832     0.034   31.7 1.697e+00 11.982     0.038   29.0 1.574e+00    1    0 0000     AA               5 57422.80411043         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.236127 227.516664
#  40.1256014 60.8792450 0.0999 0.0971  -0.0447 13.479     0.042   26.1 1.212e+00 12.782     0.055   19.6 1.187e+00    1    0 0000     AA               5 57789.82246208         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.236985 170.897390
#  40.1254843 60.8792628 0.0632 0.0585  -0.0178 12.695     0.029   37.2 1.026e+00 11.875     0.032   33.5 6.262e-01    1    0 0000     AA              10 57257.62763947         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.238713 224.616654
#  40.1254977 60.8792567 0.0729 0.0641  -0.0279 12.721     0.028   38.7 6.538e-01 12.027     0.038   28.9 1.042e+00    1    0 0000     AA              10 57064.06112774         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.240015 216.922459
#  40.1255605 60.8792439 0.0617 0.0546  -0.0138 12.585     0.025   43.0 5.139e-01 11.686     0.031   35.4 9.684e-01    1    0 0000     AA              10 56894.74014150         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.240409 188.169900
#  40.1255209 60.8792496 0.1369 0.1271   0.0358 13.535     0.062   17.4 1.013e+00 12.989     0.074   14.8 4.278e-01    1    0 0000     AA               5 57988.55960354         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.240840 205.462744
#  40.1254653 60.8792730 0.0554 0.0546  -0.0155 12.515     0.026   42.5 1.274e+00 11.694     0.029   37.0 7.392e-01    1    0 0000     AA              10 56895.00322196         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.241095 236.461321
#  40.1254947 60.8792571 0.0926 0.0975  -0.0269 13.295     0.038   28.3 8.666e-01 12.563     0.069   15.8 1.093e+00    1    0 0000     AA               5 57620.84204947         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.242073 218.121800
#  40.1254818 60.8792620 0.0863 0.0660  -0.0141 12.732     0.031   34.7 7.886e-01 11.945     0.039   27.9 6.908e-01    1    0 0000     AA               5 57257.36519552         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.243842 224.873925
#  40.1255586 60.8792430 0.0324 0.0306  -0.0064 10.860     0.016   69.8 9.851e-01 10.014     0.018   62.0 1.019e+00    1    0 0000     AA              10 56705.05631419         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.244094 188.835242
#  40.1254895 60.8792580 0.1061 0.1030  -0.0559 13.307     0.048   22.7 3.145e-01 12.577     0.061   17.9 7.500e-01    1    0 0000     AA              10 57787.59569183         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.245329 220.263317
#  40.1254436 60.8792932 0.1097 0.1163  -0.0430 13.698     0.046   23.8 1.531e+00 13.112     0.082   13.3 6.282e-01    1    0 0000     AA               5 57989.08334380         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.246501 255.797236
#  40.1255312 60.8792455 0.0308 0.0285   0.0037 10.842     0.017   65.0 1.657e+00  9.985     0.017   65.3 1.789e+00    1    0 0000     AA              10 56704.59484148         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.247438 200.213483
#  40.1255197 60.8792470 0.0306 0.0285   0.0110 10.834     0.017   64.8 1.124e+00  9.988     0.015   70.3 6.839e-01    1    0 0000     AA              10 56704.66067520         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.250191 204.975889
#  40.1255448 60.8792415 0.0575 0.0619  -0.0197 12.673     0.027   39.5 4.697e-01 11.945     0.033   33.2 7.190e-01    1    0 g000     AA              10 57064.19241328         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.254199 194.040297
#  40.1254801 60.8792580 0.0926 0.0918  -0.0333 13.274     0.036   29.9 1.866e+00 12.626     0.062   17.6 9.839e-01    1    0 0000     AA              10 57621.56265444         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.256271 223.074023
#  40.1255977 60.8792388 0.0939 0.0937  -0.0406 13.313     0.040   27.3 1.244e+00 12.710     0.056   19.5 1.145e+00    1    0 0000     AA               5 57790.08452498         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.258181 173.101909
#  40.1254558 60.8792710 0.0569 0.0597  -0.0162 12.591     0.027   39.5 1.483e+00 11.737     0.032   33.6 1.013e+00    1    0 0000     AA              10 56895.59534381         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.258948 237.168091
#  40.1254963 60.8792506 0.0950 0.1014  -0.0432 13.279     0.041   26.3 1.637e+00 12.579     0.054   20.1 1.512e+00    1    0 0000     AA              10 57621.95574638         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.259295 214.439871
#  40.1255855 60.8792380 0.0774 0.0632  -0.0271 12.713     0.033   33.2 1.666e+00 11.983     0.038   28.9 7.880e-01    1    0 0000     AA               5 57423.06630017         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.259386 177.871021
#  40.1255012 60.8792480 0.0936 0.0975  -0.0369 13.363     0.038   28.4 1.260e+00 12.740     0.054   20.0 8.724e-01    1    0 0000     AA              10 57786.87533660         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.262445 211.737578
#  40.1255031 60.8792472 0.0654 0.0692  -0.0255 12.737     0.030   36.8 5.532e-01 11.886     0.040   27.0 5.332e-01    1    0 0000     AA              10 57064.19254064         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.263182 210.791400
#  40.1255189 60.8792419 0.0719 0.0668  -0.0305 12.833     0.030   36.2 9.695e-01 11.973     0.037   29.7 1.188e+00    1    0 0000     AA              10 57422.93514167         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.267508 203.587479
#  40.1255131 60.8792431 0.1007 0.1063  -0.0344 13.220     0.037   29.1 1.197e+00 12.594     0.066   16.4 6.255e-01    1    0 0000     AA              10 57621.36604479         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.267843 205.949964
#  40.1254262 60.8793118 0.0813 0.0913  -0.0382 13.195     0.037   29.4 1.690e+00 12.593     0.048   22.4 4.203e-01    1    0 0000     AA              10 57620.97295285         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.269531 271.377713
#  40.1255345 60.8792384 0.0771 0.0691  -0.0220 12.887     0.030   35.6 1.175e+00 12.042     0.039   27.7 1.224e+00    1    0 0000     AA               5 57422.60737255         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.269811 197.184492
#  40.1255093 60.8792432 0.1514 0.1292  -0.0805 13.283     0.056   19.5 1.539e+00 12.560     0.056   19.6 9.894e-01    1    0 0000     AA               5 57625.36228978         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.270510 207.251381
#  40.1254391 60.8792782 0.0653 0.0615  -0.0141 12.743     0.030   35.8 1.411e+00 11.932     0.033   32.7 5.050e-01    1    0 0000     AA              10 57257.16845797         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.272095 245.119820
#  40.1255061 60.8792429 0.0726 0.0631  -0.0237 12.774     0.027   40.7 1.095e+00 12.028     0.045   24.0 1.041e+00    1    0 0000     AA               5 57064.32382617         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.274067 208.189973
#  40.1255827 60.8792335 0.1387 0.1426  -0.0467 13.676     0.049   22.1 1.776e+00 13.133     0.084   13.0 9.519e-01    1    0 0000     AA              10 57988.95231319         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.275442 179.015987
#  40.1254559 60.8792625 0.1087 0.1139  -0.0513 13.612     0.044   24.8 2.180e+00 13.094     0.077   14.0 1.117e+00    1    0 0000     AA              10 57988.62505512         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.276606 231.814666
#  40.1254595 60.8792600 0.0693 0.0630   0.0108 12.755     0.028   38.3 1.069e+00 11.989     0.045   23.9 4.237e-01    1    0 0000     AA              10 57257.29961633         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.277424 229.547854
#  40.1254597 60.8792598 0.0588 0.0580  -0.0127 12.570     0.025   42.6 8.361e-01 11.755     0.033   32.4 8.079e-01    1    0 0000     AA              10 56895.46367627         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.277628 229.387869
#  40.1255530 60.8792337 0.1042 0.1026  -0.0502 13.440     0.040   27.1 2.427e+00 12.816     0.112    9.7 1.075e+00    1    0 0000     AB               5 57786.61340097         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.278715 189.771054
#  40.1254759 60.8792512 0.0345 0.0303   0.0121 10.850     0.018   59.0 1.057e+00  9.986     0.018   60.5 1.658e+00    1    0 0000     AA              10 56704.92413741         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.279409 220.747295
#  40.1255699 60.8792322 0.0591 0.0574  -0.0251 12.722     0.026   42.1 1.250e+00 11.893     0.033   33.3 6.700e-01    1    0 0000     AA               5 57257.88995615         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.280640 183.614982
#  40.1254997 60.8792423 0.0323 0.0291  -0.0096 10.799     0.017   62.6 7.090e+00  9.993     0.016   66.6 3.383e+00    1    0 0000     AA               5 56704.06791720         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.281414 209.994635
#  40.1254808 60.8792481 0.1204 0.1111  -0.0368 13.595     0.042   25.8 2.200e+00 12.930     0.089   12.2 6.404e-01    1    0 0000     AA               5 57988.23221816         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.282603 217.950714
#  40.1255100 60.8792379 0.0571 0.0610  -0.0264 12.691     0.026   42.3 9.430e-01 11.935     0.034   32.2 1.060e+00    1    0 0000     AA              10 57257.43077470         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.287080 205.289693
#  40.1254809 60.8792458 0.0906 0.0957  -0.0276 13.367     0.038   28.6 2.203e+00 12.743     0.061   17.9 9.404e-01    1    0 0000     AA               5 57787.00636807         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.289064 216.913982
#  40.1254866 60.8792435 0.0942 0.1018   0.0109 13.308     0.042   25.7 2.115e+00 12.558     0.063   17.3 5.577e-01    1    0 0000     AA              10 57621.82471574         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.289978 214.352935
#  40.1256347 60.8792338 0.0912 0.0983  -0.0360 13.241     0.040   27.0 1.860e+00 12.724     0.054   20.1 6.734e-01    1    0 0000     AA               5 57621.10398350         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.290580 160.743540
#  40.1255232 60.8792335 0.0608 0.0572  -0.0245 12.665     0.030   36.2 2.808e+00 11.726     0.030   36.7 1.363e+00    1    0 0000     AA              10 56895.98996448         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.292831 199.866371
#  40.1255322 60.8792318 0.0615 0.0684   0.0133 12.636     0.032   34.3 7.589e-01 11.775     0.034   31.7 7.657e-01    1    0 0000     AA              10 56895.59521649         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.293716 196.566040
#  40.1255367 60.8792299 0.0576 0.0569  -0.0217 12.579     0.027   39.6 1.109e+00 11.752     0.035   31.4 7.967e-01    1    0 0000     AA              10 56895.26642971         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.298169 194.738940
#  40.1254196 60.8792822 0.1178 0.1068  -0.0298 13.493     0.042   26.0 1.327e+00 12.785     0.057   18.9 7.662e-01    1    0 0000     AA               5 57787.72672325         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.298296 250.397139
#  40.1254827 60.8792416 0.0314 0.0286  -0.0044 10.850     0.016   67.9 6.943e-01  9.938     0.015   70.3 1.281e+00    1    0 0000     AA              10 56705.18798156         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.299481 214.693687
#  40.1255584 60.8792265 0.0718 0.0657  -0.0155 12.767     0.030   35.6 9.792e-01 11.929     0.043   25.5 6.449e-01    1    0 0000     AA              10 57063.33861120         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.302978 187.175133
#  40.1254343 60.8792645 0.0681 0.0581  -0.0117 12.661     0.026   41.8 7.043e-01 11.916     0.033   33.0 9.168e-01    1    0 0000     AA               5 57256.97159310         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.303290 237.311655
#  40.1255203 60.8792299 0.0938 0.0860  -0.0256 13.257     0.034   31.5 1.137e+00 12.760     0.060   18.1 1.060e+00    1    0 0000     AA               5 57621.43162380         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.306743 199.936255
#  40.1255841 60.8792245 0.0785 0.0661  -0.0204 12.856     0.029   37.1 9.518e-01 12.015     0.038   28.7 1.101e+00    1    0 0000     AA               5 57423.00072095         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.307881 178.663158
#  40.1254417 60.8792564 0.1133 0.1027  -0.0411 13.425     0.041   26.8 1.100e+00 12.749     0.059   18.4 4.871e-01    1    0 0000     AA              10 57789.62597862         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.309747 231.466663
#  40.1254662 60.8792401 0.0345 0.0328  -0.0093 10.854     0.020   54.2 7.215e-01  9.965     0.015   70.2 1.434e+00    1    0 0000     AA              10 56704.79234266         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.321054 218.389412
#  40.1254657 60.8792402 0.0354 0.0278  -0.0105 10.833     0.016   68.4 9.503e-01  9.976     0.016   70.0 1.181e+00    1    0 0000     AA              10 56705.31977631         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.321304 218.551711
#  40.1254663 60.8792392 0.0328 0.0312  -0.0082 10.853     0.018   60.3 7.259e-01  9.971     0.017   64.8 8.987e-01    1    0 0000     AA              10 56704.85817633         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.323487 218.008714
#  40.1254219 60.8792634 0.1298 0.1252  -0.0450 13.691     0.047   22.9 1.296e+00 12.987     0.104   10.5 5.693e-01    1    0 0000     AA              10 57988.95244056         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.323822 238.798028
#  40.1254870 60.8792322 0.1237 0.1072  -0.0389 13.395     0.043   25.1 8.620e-01 12.683     0.064   17.0 3.434e-01    1    0 0000     AA               5 57790.60839591         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.324026 210.187885
#  40.1254358 60.8792513 0.1184 0.1005  -0.0255 13.409     0.046   23.8 1.215e+00 12.628     0.052   21.1 9.763e-01    1    0 0000     AA               5 57620.71101873         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.329362 230.088296
#  40.1254461 60.8792452 0.0629 0.0619  -0.0208 12.737     0.027   40.3 1.093e+00 11.983     0.040   27.2 5.319e-01    1    0 0000     AA              10 57063.92971476         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.330835 225.159923
#  40.1255125 60.8792231 0.1031 0.1029  -0.0400 13.492     0.043   25.0 8.661e-01 12.865     0.064   16.9 7.424e-01    1    0 0000     AA              10 57787.59581919         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.334442 200.707071
#  40.1254618 60.8792360 0.1083 0.1079  -0.0407 13.638     0.042   25.6 1.492e+00 13.032     0.065   16.6 1.026e+00    1    0 0000     AA               5 57988.42857294         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.337423 217.858940
#  40.1255300 60.8792179 0.1152 0.1011  -0.0334 13.470     0.040   27.4 1.075e+00 12.836     0.063   17.3 1.123e+00    1    0 0000     AA               5 57790.14997700         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.342936 194.799271
#  40.1255402 60.8792164 0.0649 0.0608  -0.0255 12.726     0.034   31.6 1.146e+00 11.970     0.035   31.1 1.366e+00    1    0 0000     AA              10 57063.20719831         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.344104 191.691274
#  40.1256318 60.8792169 0.1079 0.1071  -0.0247 13.356     0.040   26.9 9.381e-01 12.843     0.071   15.3 8.953e-01    1    0 0000     AA              10 57786.74430513         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.347234 164.849367
#  40.1253965 60.8792698 0.0834 0.0837  -0.0272 13.197     0.035   31.2 9.391e-01 12.596     0.058   18.6 5.684e-01    1    0 0000     AA              10 57620.97308016         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.352552 245.764450
#  40.1257386 60.8792490 0.1465 0.1449  -0.0558 13.727     0.064   16.9 9.872e-01 13.285     0.096   11.3 6.603e-01    1    0 0000     AA               5 57988.69050670         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.354157 128.320323
#  40.1254460 60.8792341 0.0693 0.0685   0.0010 12.814     0.030   36.6 9.335e-01 11.920     0.034   32.0 1.536e+00    1    0 0000     AA               5 57422.86956238         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.360239 220.668368
#  40.1255813 60.8792095 0.0774 0.0708   0.0298 12.803     0.035   31.5 1.765e+00 11.958     0.039   27.9 8.061e-01    1    0 0000     AA              10 57064.12683421         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.361809 179.639327
#  40.1254261 60.8792422 0.0566 0.0604  -0.0231 12.570     0.030   36.5 1.177e+00 11.735     0.035   31.1 1.315e+00    1    0 0000     AA              10 56895.13488954         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.363697 227.846798
#  40.1254712 60.8792222 0.0934 0.1036  -0.0309 13.363     0.038   28.2 1.793e+00 12.748     0.057   19.2 7.107e-01    1    0 0000     AA               5 57790.08439760         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.369112 211.092077
#  40.1254678 60.8792187 0.1061 0.0965  -0.0289 13.424     0.039   27.8 1.275e+00 12.812     0.061   17.9 9.367e-01    1    0 0000     AA              10 57787.39933507         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.382979 210.881741
#  40.1254919 60.8792120 0.0641 0.0598  -0.0116 12.775     0.028   38.2 2.297e+00 11.866     0.033   32.6 1.181e+00    1    0 0000     AA              10 57063.73272271         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.385082 203.628929
#  40.1254533 60.8792216 0.1392 0.1355  -0.0157 13.752     0.052   21.0 1.312e+00 13.027     0.082   13.3 5.648e-01    1    0 0000     AA               5 57988.10131495         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.388003 214.895720
#  40.1254765 60.8792145 0.0693 0.0593  -0.0215 12.771     0.027   39.6 1.235e+00 11.912     0.030   35.7 7.525e-01    1    0 0000     AA              10 57423.26291069         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.388684 207.808027
#  40.1255152 60.8792034 0.0996 0.1017  -0.0465 13.317     0.040   27.1 7.757e-01 12.714     0.052   20.9 6.854e-01    1    0 0000     AA              10 57790.28088106         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.400204 196.479604
#  40.1255455 60.8791987 0.0624 0.0637  -0.0253 12.784     0.027   39.5 6.670e-01 11.892     0.045   24.3 7.875e-01    1    0 0000     AA              10 57063.60130977         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.405212 188.578344
#  40.1254128 60.8792308 0.1117 0.0983  -0.0327 13.390     0.038   28.8 1.199e+00 12.867     0.073   14.8 6.376e-01    1    0 0000     AA              10 57787.26830360         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.408775 225.773682
#  40.1255488 60.8791972 0.1106 0.1071  -0.0409 13.323     0.041   26.4 9.945e-01 12.639     0.065   16.6 7.000e-01    1    0 0000     AA               5 57621.49707549         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.409745 187.666278
#  40.1255041 60.8792023 0.1058 0.1041  -0.0286 13.424     0.038   28.3 1.588e+00 12.937     0.097   11.2 7.109e-01    1    0 0000     AA              10 57789.95349355         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.409883 198.929985
#  40.1254421 60.8792179 0.0626 0.0649  -0.0298 12.727     0.029   37.5 1.939e+00 11.886     0.034   31.8 7.438e-01    1    0 0000     AA              10 57423.19733141         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.410240 216.079251
#  40.1254363 60.8792199 0.0884 0.0961  -0.0319 13.359     0.038   28.5 1.636e+00 12.860     0.066   16.4 6.379e-01    1    0 0000     AA              10 57789.88804147         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.410597 217.817173
#  40.1254819 60.8792058 0.1017 0.1033  -0.0525 13.388     0.039   27.5 1.004e+00 12.771     0.067   16.2 5.198e-01    1    0 0000     AA              10 57787.07182015         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.412617 204.615517
#  40.1255084 60.8792008 0.0595 0.0601  -0.0209 12.729     0.028   39.0 1.033e+00 11.968     0.035   31.4 5.957e-01    1    0 0000     AA              10 57063.66701624         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.412651 197.697220
#  40.1254239 60.8792209 0.1131 0.1030  -0.0190 13.339     0.043   25.2 1.214e+00 12.810     0.064   16.8 5.109e-01    1    0 0000     AA               5 57787.20285157         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.421518 220.450847
#  40.1255101 60.8791979 0.0688 0.0660  -0.0268 12.827     0.029   36.9 1.146e+00 11.981     0.032   33.5 9.383e-01    1    0 0000     AA              10 57423.59067975         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.421731 196.880550
#  40.1255504 60.8791936 0.1250 0.1098  -0.0364 13.614     0.041   26.4 2.587e+00 13.135     0.088   12.3 7.825e-01    1    0 0000     AA               5 57987.83938105         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.422235 187.054691
#  40.1254655 60.8792057 0.0295 0.0298   0.0088 10.848     0.017   62.8 6.484e+00  9.962     0.016   67.8 2.115e+00    1    0 0000     AA              10 56704.85830365         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.425700 208.113130
#  40.1255491 60.8791925 0.1361 0.1355  -0.0620 13.705     0.049   22.3 6.866e-01 12.985     0.085   12.8 5.531e-01    1    0 0000     AA               5 57988.82140999         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.426454 187.293029
#  40.1253863 60.8792324 0.1362 0.1200  -0.0418 13.803     0.049   22.3 7.825e-01 13.145     0.071   15.2 8.457e-01    1    0 0000     AA               5 57988.16676654         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.439544 230.538310
#  40.1254017 60.8792188 0.1756 0.1349  -0.0354 13.417     0.080   13.5 1.913e+00 12.771     0.072   15.2 4.021e-01    1    0 0000     AA              10 57790.47736456         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.453174 223.574167
#  40.1254504 60.8791953 0.0650 0.0627  -0.0236 12.829     0.031   35.0 2.803e+00 11.903     0.037   29.2 1.251e+00    1    0 0000     AA               5 57423.45964858         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.471232 208.805123
#  40.1254195 60.8791910 0.0736 0.0604  -0.0255 12.777     0.027   39.9 8.821e-01 11.964     0.033   33.1 8.097e-01    1    0 0000     AA              10 57063.99542123         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.512441 213.279623
#  40.1253594 60.8792163 0.0631 0.0675  -0.0093 12.791     0.030   36.6 1.130e+00 11.972     0.039   27.5 6.409e-01    1    0 0000     AA              10 57422.73853115         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.512985 228.885562
#  40.1252771 60.8793411 0.1150 0.1078  -0.0397 13.511     0.041   26.2 1.299e+00 12.668     0.061   17.8 6.642e-01    1    0 0000     AA               5 57790.01894558         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.542346 281.913746
#  40.1253172 60.8792186 0.1035 0.1091  -0.0272 13.328     0.038   28.6 1.868e+00 12.893     0.091   11.9 1.075e+00    1    0 0000     AA               5 57790.21542903         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.565899 234.448038
#  40.1256247 60.8791518 0.1463 0.1293  -0.0575 13.734     0.048   22.9 9.954e-01 13.257     0.122    8.9 5.377e-01    1    0 0000     AB               5 57988.36312131         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.574875 172.170603
#  40.1252789 60.8792352 0.1174 0.1057  -0.0497 13.360     0.049   22.3 7.856e-01 12.729     0.060   18.1 7.291e-01    1    0 0000     AA               5 57787.33375567         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.592270 242.957045
#  40.1260438 60.8791845 0.1911 0.1661  -0.0549 14.036     0.070   15.4 4.369e+00 13.472     0.094   11.6 1.701e+00    1    0 0000     AA               0 57988.49402461         null           null              null           null              null           null              null           null              null      null      null         null      null         null      null         null 0.929713 119.074968

# %%
irsa_tbl_filepath = '/Users/kylerocha/Private/data/dsfp_Session15_wrangling/irsa_catalog_WISE_iPTF14jg_search_results.tbl'

names_raw = np.loadtxt(irsa_tbl_filepath, 
                       skiprows=89,max_rows=1, dtype=str)
print(names_raw)
names_cleaned = [n.split('|')[-1] for n in names_raw if n != '|']

print(names_cleaned)
# Out:
# ['|ra' '|dec' '|sigra' '|sigdec|sigradec|w1mpro|w1sigmpro|w1snr'
#  '|w1rchi2' '|w2mpro|w2sigmpro|w2snr' '|w2rchi2' '|nb' '|na'
#  '|cc_flags|ph_qual|qual_frame|mjd'
#  '|allwise_cntr|w1mpro_allwise|w1sigmpro_allwise|w2mpro_allwise|w2sigmpro_allwise|w3mpro_allwise|w3sigmpro_allwise|w4mpro_allwise|w4sigmpro_allwise|tmass_key|j_m_2mass|j_msig_2mass|h_m_2mass|h_msig_2mass|k_m_2mass|k_msig_2mass|dist'
#  '|angle' '|']
# ['ra', 'dec', 'sigra', 'w1snr', 'w1rchi2', 'w2snr', 'w2rchi2', 'nb', 'na', 'mjd', 'dist', 'angle']

# %%
# Use pandas to read in the IRSA data
pd.read_csv( irsa_tbl_filepath, 
            comment="\\", delim_whitespace=True, skiprows=93, names=names_cleaned)
# Out:
#                                                                                                                                                  ra  \
# 40.125566 60.879306 0.0947 0.0936 -0.0337 13.251 0.038 28.8 0.8767 12.735 0.058 18.6 0.7135 1 0 0000 AA 10 57621.235014 NaN NaN NaN NaN NaN NaN NaN
# 40.125574 60.879297 0.0925 0.0874 -0.0397 13.241 0.036 30.0 1.2610 12.629 0.051 21.2 1.1210 1 0 0000 AA 5  57621.628106 NaN NaN NaN NaN NaN NaN NaN
# 40.125623 60.879318 0.0808 0.0794  0.0098 12.753 0.039 27.8 0.7640 11.901 0.034 32.0 1.0590 1 0 0000 AA 10 57063.798302 NaN NaN NaN NaN NaN NaN NaN
# 40.125553 60.879286 0.0663 0.0608 -0.0156 12.774 0.028 38.6 1.3610 11.935 0.037 29.3 0.7133 1 0 0000 AA 10 57256.774856 NaN NaN NaN NaN NaN NaN NaN
# 40.125572 60.879280 0.0645 0.0599 -0.0223 12.840 0.028 38.7 1.5550 11.897 0.031 35.1 1.0450 1 0 0000 AA 5  57257.102751 NaN NaN NaN NaN NaN NaN NaN
# ...                                                                                                                                              ..
# 40.125277 60.879341 0.1150 0.1078 -0.0397 13.511 0.041 26.2 1.2990 12.668 0.061 17.8 0.6642 1 0 0000 AA 5  57790.018946 NaN NaN NaN NaN NaN NaN NaN
# 40.125317 60.879219 0.1035 0.1091 -0.0272 13.328 0.038 28.6 1.8680 12.893 0.091 11.9 1.0750 1 0 0000 AA 5  57790.215429 NaN NaN NaN NaN NaN NaN NaN
# 40.125625 60.879152 0.1463 0.1293 -0.0575 13.734 0.048 22.9 0.9954 13.257 0.122 8.9  0.5377 1 0 0000 AB 5  57988.363121 NaN NaN NaN NaN NaN NaN NaN
# 40.125279 60.879235 0.1174 0.1057 -0.0497 13.360 0.049 22.3 0.7856 12.729 0.060 18.1 0.7291 1 0 0000 AA 5  57787.333756 NaN NaN NaN NaN NaN NaN NaN
# 40.126044 60.879185 0.1911 0.1661 -0.0549 14.036 0.070 15.4 4.3690 13.472 0.094 11.6 1.7010 1 0 0000 AA 0  57988.494025 NaN NaN NaN NaN NaN NaN NaN
#
#                                                                                                                                                  dec  \
# 40.125566 60.879306 0.0947 0.0936 -0.0337 13.251 0.038 28.8 0.8767 12.735 0.058 18.6 0.7135 1 0 0000 AA 10 57621.235014 NaN NaN NaN NaN NaN NaN  NaN
# 40.125574 60.879297 0.0925 0.0874 -0.0397 13.241 0.036 30.0 1.2610 12.629 0.051 21.2 1.1210 1 0 0000 AA 5  57621.628106 NaN NaN NaN NaN NaN NaN  NaN
# 40.125623 60.879318 0.0808 0.0794  0.0098 12.753 0.039 27.8 0.7640 11.901 0.034 32.0 1.0590 1 0 0000 AA 10 57063.798302 NaN NaN NaN NaN NaN NaN  NaN
# 40.125553 60.879286 0.0663 0.0608 -0.0156 12.774 0.028 38.6 1.3610 11.935 0.037 29.3 0.7133 1 0 0000 AA 10 57256.774856 NaN NaN NaN NaN NaN NaN  NaN
# 40.125572 60.879280 0.0645 0.0599 -0.0223 12.840 0.028 38.7 1.5550 11.897 0.031 35.1 1.0450 1 0 0000 AA 5  57257.102751 NaN NaN NaN NaN NaN NaN  NaN
# ...                                                                                                                                              ...
# 40.125277 60.879341 0.1150 0.1078 -0.0397 13.511 0.041 26.2 1.2990 12.668 0.061 17.8 0.6642 1 0 0000 AA 5  57790.018946 NaN NaN NaN NaN NaN NaN  NaN
# 40.125317 60.879219 0.1035 0.1091 -0.0272 13.328 0.038 28.6 1.8680 12.893 0.091 11.9 1.0750 1 0 0000 AA 5  57790.215429 NaN NaN NaN NaN NaN NaN  NaN
# 40.125625 60.879152 0.1463 0.1293 -0.0575 13.734 0.048 22.9 0.9954 13.257 0.122 8.9  0.5377 1 0 0000 AB 5  57988.363121 NaN NaN NaN NaN NaN NaN  NaN
# 40.125279 60.879235 0.1174 0.1057 -0.0497 13.360 0.049 22.3 0.7856 12.729 0.060 18.1 0.7291 1 0 0000 AA 5  57787.333756 NaN NaN NaN NaN NaN NaN  NaN
# 40.126044 60.879185 0.1911 0.1661 -0.0549 14.036 0.070 15.4 4.3690 13.472 0.094 11.6 1.7010 1 0 0000 AA 0  57988.494025 NaN NaN NaN NaN NaN NaN  NaN
#
#                                                                                                                                                  sigra  \
# 40.125566 60.879306 0.0947 0.0936 -0.0337 13.251 0.038 28.8 0.8767 12.735 0.058 18.6 0.7135 1 0 0000 AA 10 57621.235014 NaN NaN NaN NaN NaN NaN    NaN
# 40.125574 60.879297 0.0925 0.0874 -0.0397 13.241 0.036 30.0 1.2610 12.629 0.051 21.2 1.1210 1 0 0000 AA 5  57621.628106 NaN NaN NaN NaN NaN NaN    NaN
# 40.125623 60.879318 0.0808 0.0794  0.0098 12.753 0.039 27.8 0.7640 11.901 0.034 32.0 1.0590 1 0 0000 AA 10 57063.798302 NaN NaN NaN NaN NaN NaN    NaN
# 40.125553 60.879286 0.0663 0.0608 -0.0156 12.774 0.028 38.6 1.3610 11.935 0.037 29.3 0.7133 1 0 0000 AA 10 57256.774856 NaN NaN NaN NaN NaN NaN    NaN
# 40.125572 60.879280 0.0645 0.0599 -0.0223 12.840 0.028 38.7 1.5550 11.897 0.031 35.1 1.0450 1 0 0000 AA 5  57257.102751 NaN NaN NaN NaN NaN NaN    NaN
# ...                                                                                                                                                ...
# 40.125277 60.879341 0.1150 0.1078 -0.0397 13.511 0.041 26.2 1.2990 12.668 0.061 17.8 0.6642 1 0 0000 AA 5  57790.018946 NaN NaN NaN NaN NaN NaN    NaN
# 40.125317 60.879219 0.1035 0.1091 -0.0272 13.328 0.038 28.6 1.8680 12.893 0.091 11.9 1.0750 1 0 0000 AA 5  57790.215429 NaN NaN NaN NaN NaN NaN    NaN
# 40.125625 60.879152 0.1463 0.1293 -0.0575 13.734 0.048 22.9 0.9954 13.257 0.122 8.9  0.5377 1 0 0000 AB 5  57988.363121 NaN NaN NaN NaN NaN NaN    NaN
# 40.125279 60.879235 0.1174 0.1057 -0.0497 13.360 0.049 22.3 0.7856 12.729 0.060 18.1 0.7291 1 0 0000 AA 5  57787.333756 NaN NaN NaN NaN NaN NaN    NaN
# 40.126044 60.879185 0.1911 0.1661 -0.0549 14.036 0.070 15.4 4.3690 13.472 0.094 11.6 1.7010 1 0 0000 AA 0  57988.494025 NaN NaN NaN NaN NaN NaN    NaN
#
#                                                                                                                                                  w1snr  \
# 40.125566 60.879306 0.0947 0.0936 -0.0337 13.251 0.038 28.8 0.8767 12.735 0.058 18.6 0.7135 1 0 0000 AA 10 57621.235014 NaN NaN NaN NaN NaN NaN    NaN
# 40.125574 60.879297 0.0925 0.0874 -0.0397 13.241 0.036 30.0 1.2610 12.629 0.051 21.2 1.1210 1 0 0000 AA 5  57621.628106 NaN NaN NaN NaN NaN NaN    NaN
# 40.125623 60.879318 0.0808 0.0794  0.0098 12.753 0.039 27.8 0.7640 11.901 0.034 32.0 1.0590 1 0 0000 AA 10 57063.798302 NaN NaN NaN NaN NaN NaN    NaN
# 40.125553 60.879286 0.0663 0.0608 -0.0156 12.774 0.028 38.6 1.3610 11.935 0.037 29.3 0.7133 1 0 0000 AA 10 57256.774856 NaN NaN NaN NaN NaN NaN    NaN
# 40.125572 60.879280 0.0645 0.0599 -0.0223 12.840 0.028 38.7 1.5550 11.897 0.031 35.1 1.0450 1 0 0000 AA 5  57257.102751 NaN NaN NaN NaN NaN NaN    NaN
# ...                                                                                                                                                ...
# 40.125277 60.879341 0.1150 0.1078 -0.0397 13.511 0.041 26.2 1.2990 12.668 0.061 17.8 0.6642 1 0 0000 AA 5  57790.018946 NaN NaN NaN NaN NaN NaN    NaN
# 40.125317 60.879219 0.1035 0.1091 -0.0272 13.328 0.038 28.6 1.8680 12.893 0.091 11.9 1.0750 1 0 0000 AA 5  57790.215429 NaN NaN NaN NaN NaN NaN    NaN
# 40.125625 60.879152 0.1463 0.1293 -0.0575 13.734 0.048 22.9 0.9954 13.257 0.122 8.9  0.5377 1 0 0000 AB 5  57988.363121 NaN NaN NaN NaN NaN NaN    NaN
# 40.125279 60.879235 0.1174 0.1057 -0.0497 13.360 0.049 22.3 0.7856 12.729 0.060 18.1 0.7291 1 0 0000 AA 5  57787.333756 NaN NaN NaN NaN NaN NaN    NaN
# 40.126044 60.879185 0.1911 0.1661 -0.0549 14.036 0.070 15.4 4.3690 13.472 0.094 11.6 1.7010 1 0 0000 AA 0  57988.494025 NaN NaN NaN NaN NaN NaN    NaN
#
#                                                                                                                                                  w1rchi2  \
# 40.125566 60.879306 0.0947 0.0936 -0.0337 13.251 0.038 28.8 0.8767 12.735 0.058 18.6 0.7135 1 0 0000 AA 10 57621.235014 NaN NaN NaN NaN NaN NaN      NaN
# 40.125574 60.879297 0.0925 0.0874 -0.0397 13.241 0.036 30.0 1.2610 12.629 0.051 21.2 1.1210 1 0 0000 AA 5  57621.628106 NaN NaN NaN NaN NaN NaN      NaN
# 40.125623 60.879318 0.0808 0.0794  0.0098 12.753 0.039 27.8 0.7640 11.901 0.034 32.0 1.0590 1 0 0000 AA 10 57063.798302 NaN NaN NaN NaN NaN NaN      NaN
# 40.125553 60.879286 0.0663 0.0608 -0.0156 12.774 0.028 38.6 1.3610 11.935 0.037 29.3 0.7133 1 0 0000 AA 10 57256.774856 NaN NaN NaN NaN NaN NaN      NaN
# 40.125572 60.879280 0.0645 0.0599 -0.0223 12.840 0.028 38.7 1.5550 11.897 0.031 35.1 1.0450 1 0 0000 AA 5  57257.102751 NaN NaN NaN NaN NaN NaN      NaN
# ...                                                                                                                                                  ...
# 40.125277 60.879341 0.1150 0.1078 -0.0397 13.511 0.041 26.2 1.2990 12.668 0.061 17.8 0.6642 1 0 0000 AA 5  57790.018946 NaN NaN NaN NaN NaN NaN      NaN
# 40.125317 60.879219 0.1035 0.1091 -0.0272 13.328 0.038 28.6 1.8680 12.893 0.091 11.9 1.0750 1 0 0000 AA 5  57790.215429 NaN NaN NaN NaN NaN NaN      NaN
# 40.125625 60.879152 0.1463 0.1293 -0.0575 13.734 0.048 22.9 0.9954 13.257 0.122 8.9  0.5377 1 0 0000 AB 5  57988.363121 NaN NaN NaN NaN NaN NaN      NaN
# 40.125279 60.879235 0.1174 0.1057 -0.0497 13.360 0.049 22.3 0.7856 12.729 0.060 18.1 0.7291 1 0 0000 AA 5  57787.333756 NaN NaN NaN NaN NaN NaN      NaN
# 40.126044 60.879185 0.1911 0.1661 -0.0549 14.036 0.070 15.4 4.3690 13.472 0.094 11.6 1.7010 1 0 0000 AA 0  57988.494025 NaN NaN NaN NaN NaN NaN      NaN
#
#                                                                                                                                                  w2snr  \
# 40.125566 60.879306 0.0947 0.0936 -0.0337 13.251 0.038 28.8 0.8767 12.735 0.058 18.6 0.7135 1 0 0000 AA 10 57621.235014 NaN NaN NaN NaN NaN NaN    NaN
# 40.125574 60.879297 0.0925 0.0874 -0.0397 13.241 0.036 30.0 1.2610 12.629 0.051 21.2 1.1210 1 0 0000 AA 5  57621.628106 NaN NaN NaN NaN NaN NaN    NaN
# 40.125623 60.879318 0.0808 0.0794  0.0098 12.753 0.039 27.8 0.7640 11.901 0.034 32.0 1.0590 1 0 0000 AA 10 57063.798302 NaN NaN NaN NaN NaN NaN    NaN
# 40.125553 60.879286 0.0663 0.0608 -0.0156 12.774 0.028 38.6 1.3610 11.935 0.037 29.3 0.7133 1 0 0000 AA 10 57256.774856 NaN NaN NaN NaN NaN NaN    NaN
# 40.125572 60.879280 0.0645 0.0599 -0.0223 12.840 0.028 38.7 1.5550 11.897 0.031 35.1 1.0450 1 0 0000 AA 5  57257.102751 NaN NaN NaN NaN NaN NaN    NaN
# ...                                                                                                                                                ...
# 40.125277 60.879341 0.1150 0.1078 -0.0397 13.511 0.041 26.2 1.2990 12.668 0.061 17.8 0.6642 1 0 0000 AA 5  57790.018946 NaN NaN NaN NaN NaN NaN    NaN
# 40.125317 60.879219 0.1035 0.1091 -0.0272 13.328 0.038 28.6 1.8680 12.893 0.091 11.9 1.0750 1 0 0000 AA 5  57790.215429 NaN NaN NaN NaN NaN NaN    NaN
# 40.125625 60.879152 0.1463 0.1293 -0.0575 13.734 0.048 22.9 0.9954 13.257 0.122 8.9  0.5377 1 0 0000 AB 5  57988.363121 NaN NaN NaN NaN NaN NaN    NaN
# 40.125279 60.879235 0.1174 0.1057 -0.0497 13.360 0.049 22.3 0.7856 12.729 0.060 18.1 0.7291 1 0 0000 AA 5  57787.333756 NaN NaN NaN NaN NaN NaN    NaN
# 40.126044 60.879185 0.1911 0.1661 -0.0549 14.036 0.070 15.4 4.3690 13.472 0.094 11.6 1.7010 1 0 0000 AA 0  57988.494025 NaN NaN NaN NaN NaN NaN    NaN
#
#                                                                                                                                                  w2rchi2  \
# 40.125566 60.879306 0.0947 0.0936 -0.0337 13.251 0.038 28.8 0.8767 12.735 0.058 18.6 0.7135 1 0 0000 AA 10 57621.235014 NaN NaN NaN NaN NaN NaN      NaN
# 40.125574 60.879297 0.0925 0.0874 -0.0397 13.241 0.036 30.0 1.2610 12.629 0.051 21.2 1.1210 1 0 0000 AA 5  57621.628106 NaN NaN NaN NaN NaN NaN      NaN
# 40.125623 60.879318 0.0808 0.0794  0.0098 12.753 0.039 27.8 0.7640 11.901 0.034 32.0 1.0590 1 0 0000 AA 10 57063.798302 NaN NaN NaN NaN NaN NaN      NaN
# 40.125553 60.879286 0.0663 0.0608 -0.0156 12.774 0.028 38.6 1.3610 11.935 0.037 29.3 0.7133 1 0 0000 AA 10 57256.774856 NaN NaN NaN NaN NaN NaN      NaN
# 40.125572 60.879280 0.0645 0.0599 -0.0223 12.840 0.028 38.7 1.5550 11.897 0.031 35.1 1.0450 1 0 0000 AA 5  57257.102751 NaN NaN NaN NaN NaN NaN      NaN
# ...                                                                                                                                                  ...
# 40.125277 60.879341 0.1150 0.1078 -0.0397 13.511 0.041 26.2 1.2990 12.668 0.061 17.8 0.6642 1 0 0000 AA 5  57790.018946 NaN NaN NaN NaN NaN NaN      NaN
# 40.125317 60.879219 0.1035 0.1091 -0.0272 13.328 0.038 28.6 1.8680 12.893 0.091 11.9 1.0750 1 0 0000 AA 5  57790.215429 NaN NaN NaN NaN NaN NaN      NaN
# 40.125625 60.879152 0.1463 0.1293 -0.0575 13.734 0.048 22.9 0.9954 13.257 0.122 8.9  0.5377 1 0 0000 AB 5  57988.363121 NaN NaN NaN NaN NaN NaN      NaN
# 40.125279 60.879235 0.1174 0.1057 -0.0497 13.360 0.049 22.3 0.7856 12.729 0.060 18.1 0.7291 1 0 0000 AA 5  57787.333756 NaN NaN NaN NaN NaN NaN      NaN
# 40.126044 60.879185 0.1911 0.1661 -0.0549 14.036 0.070 15.4 4.3690 13.472 0.094 11.6 1.7010 1 0 0000 AA 0  57988.494025 NaN NaN NaN NaN NaN NaN      NaN
#
#                                                                                                                                                  nb  \
# 40.125566 60.879306 0.0947 0.0936 -0.0337 13.251 0.038 28.8 0.8767 12.735 0.058 18.6 0.7135 1 0 0000 AA 10 57621.235014 NaN NaN NaN NaN NaN NaN NaN
# 40.125574 60.879297 0.0925 0.0874 -0.0397 13.241 0.036 30.0 1.2610 12.629 0.051 21.2 1.1210 1 0 0000 AA 5  57621.628106 NaN NaN NaN NaN NaN NaN NaN
# 40.125623 60.879318 0.0808 0.0794  0.0098 12.753 0.039 27.8 0.7640 11.901 0.034 32.0 1.0590 1 0 0000 AA 10 57063.798302 NaN NaN NaN NaN NaN NaN NaN
# 40.125553 60.879286 0.0663 0.0608 -0.0156 12.774 0.028 38.6 1.3610 11.935 0.037 29.3 0.7133 1 0 0000 AA 10 57256.774856 NaN NaN NaN NaN NaN NaN NaN
# 40.125572 60.879280 0.0645 0.0599 -0.0223 12.840 0.028 38.7 1.5550 11.897 0.031 35.1 1.0450 1 0 0000 AA 5  57257.102751 NaN NaN NaN NaN NaN NaN NaN
# ...                                                                                                                                              ..
# 40.125277 60.879341 0.1150 0.1078 -0.0397 13.511 0.041 26.2 1.2990 12.668 0.061 17.8 0.6642 1 0 0000 AA 5  57790.018946 NaN NaN NaN NaN NaN NaN NaN
# 40.125317 60.879219 0.1035 0.1091 -0.0272 13.328 0.038 28.6 1.8680 12.893 0.091 11.9 1.0750 1 0 0000 AA 5  57790.215429 NaN NaN NaN NaN NaN NaN NaN
# 40.125625 60.879152 0.1463 0.1293 -0.0575 13.734 0.048 22.9 0.9954 13.257 0.122 8.9  0.5377 1 0 0000 AB 5  57988.363121 NaN NaN NaN NaN NaN NaN NaN
# 40.125279 60.879235 0.1174 0.1057 -0.0497 13.360 0.049 22.3 0.7856 12.729 0.060 18.1 0.7291 1 0 0000 AA 5  57787.333756 NaN NaN NaN NaN NaN NaN NaN
# 40.126044 60.879185 0.1911 0.1661 -0.0549 14.036 0.070 15.4 4.3690 13.472 0.094 11.6 1.7010 1 0 0000 AA 0  57988.494025 NaN NaN NaN NaN NaN NaN NaN
#
#                                                                                                                                                  na  \
# 40.125566 60.879306 0.0947 0.0936 -0.0337 13.251 0.038 28.8 0.8767 12.735 0.058 18.6 0.7135 1 0 0000 AA 10 57621.235014 NaN NaN NaN NaN NaN NaN NaN
# 40.125574 60.879297 0.0925 0.0874 -0.0397 13.241 0.036 30.0 1.2610 12.629 0.051 21.2 1.1210 1 0 0000 AA 5  57621.628106 NaN NaN NaN NaN NaN NaN NaN
# 40.125623 60.879318 0.0808 0.0794  0.0098 12.753 0.039 27.8 0.7640 11.901 0.034 32.0 1.0590 1 0 0000 AA 10 57063.798302 NaN NaN NaN NaN NaN NaN NaN
# 40.125553 60.879286 0.0663 0.0608 -0.0156 12.774 0.028 38.6 1.3610 11.935 0.037 29.3 0.7133 1 0 0000 AA 10 57256.774856 NaN NaN NaN NaN NaN NaN NaN
# 40.125572 60.879280 0.0645 0.0599 -0.0223 12.840 0.028 38.7 1.5550 11.897 0.031 35.1 1.0450 1 0 0000 AA 5  57257.102751 NaN NaN NaN NaN NaN NaN NaN
# ...                                                                                                                                              ..
# 40.125277 60.879341 0.1150 0.1078 -0.0397 13.511 0.041 26.2 1.2990 12.668 0.061 17.8 0.6642 1 0 0000 AA 5  57790.018946 NaN NaN NaN NaN NaN NaN NaN
# 40.125317 60.879219 0.1035 0.1091 -0.0272 13.328 0.038 28.6 1.8680 12.893 0.091 11.9 1.0750 1 0 0000 AA 5  57790.215429 NaN NaN NaN NaN NaN NaN NaN
# 40.125625 60.879152 0.1463 0.1293 -0.0575 13.734 0.048 22.9 0.9954 13.257 0.122 8.9  0.5377 1 0 0000 AB 5  57988.363121 NaN NaN NaN NaN NaN NaN NaN
# 40.125279 60.879235 0.1174 0.1057 -0.0497 13.360 0.049 22.3 0.7856 12.729 0.060 18.1 0.7291 1 0 0000 AA 5  57787.333756 NaN NaN NaN NaN NaN NaN NaN
# 40.126044 60.879185 0.1911 0.1661 -0.0549 14.036 0.070 15.4 4.3690 13.472 0.094 11.6 1.7010 1 0 0000 AA 0  57988.494025 NaN NaN NaN NaN NaN NaN NaN
#
#                                                                                                                                                  mjd  \
# 40.125566 60.879306 0.0947 0.0936 -0.0337 13.251 0.038 28.8 0.8767 12.735 0.058 18.6 0.7135 1 0 0000 AA 10 57621.235014 NaN NaN NaN NaN NaN NaN  NaN
# 40.125574 60.879297 0.0925 0.0874 -0.0397 13.241 0.036 30.0 1.2610 12.629 0.051 21.2 1.1210 1 0 0000 AA 5  57621.628106 NaN NaN NaN NaN NaN NaN  NaN
# 40.125623 60.879318 0.0808 0.0794  0.0098 12.753 0.039 27.8 0.7640 11.901 0.034 32.0 1.0590 1 0 0000 AA 10 57063.798302 NaN NaN NaN NaN NaN NaN  NaN
# 40.125553 60.879286 0.0663 0.0608 -0.0156 12.774 0.028 38.6 1.3610 11.935 0.037 29.3 0.7133 1 0 0000 AA 10 57256.774856 NaN NaN NaN NaN NaN NaN  NaN
# 40.125572 60.879280 0.0645 0.0599 -0.0223 12.840 0.028 38.7 1.5550 11.897 0.031 35.1 1.0450 1 0 0000 AA 5  57257.102751 NaN NaN NaN NaN NaN NaN  NaN
# ...                                                                                                                                              ...
# 40.125277 60.879341 0.1150 0.1078 -0.0397 13.511 0.041 26.2 1.2990 12.668 0.061 17.8 0.6642 1 0 0000 AA 5  57790.018946 NaN NaN NaN NaN NaN NaN  NaN
# 40.125317 60.879219 0.1035 0.1091 -0.0272 13.328 0.038 28.6 1.8680 12.893 0.091 11.9 1.0750 1 0 0000 AA 5  57790.215429 NaN NaN NaN NaN NaN NaN  NaN
# 40.125625 60.879152 0.1463 0.1293 -0.0575 13.734 0.048 22.9 0.9954 13.257 0.122 8.9  0.5377 1 0 0000 AB 5  57988.363121 NaN NaN NaN NaN NaN NaN  NaN
# 40.125279 60.879235 0.1174 0.1057 -0.0497 13.360 0.049 22.3 0.7856 12.729 0.060 18.1 0.7291 1 0 0000 AA 5  57787.333756 NaN NaN NaN NaN NaN NaN  NaN
# 40.126044 60.879185 0.1911 0.1661 -0.0549 14.036 0.070 15.4 4.3690 13.472 0.094 11.6 1.7010 1 0 0000 AA 0  57988.494025 NaN NaN NaN NaN NaN NaN  NaN
#
#                                                                                                                                                      dist  \
# 40.125566 60.879306 0.0947 0.0936 -0.0337 13.251 0.038 28.8 0.8767 12.735 0.058 18.6 0.7135 1 0 0000 AA 10 57621.235014 NaN NaN NaN NaN NaN NaN  0.028668
# 40.125574 60.879297 0.0925 0.0874 -0.0397 13.241 0.036 30.0 1.2610 12.629 0.051 21.2 1.1210 1 0 0000 AA 5  57621.628106 NaN NaN NaN NaN NaN NaN  0.048011
# 40.125623 60.879318 0.0808 0.0794  0.0098 12.753 0.039 27.8 0.7640 11.901 0.034 32.0 1.0590 1 0 0000 AA 10 57063.798302 NaN NaN NaN NaN NaN NaN  0.079498
# 40.125553 60.879286 0.0663 0.0608 -0.0156 12.774 0.028 38.6 1.3610 11.935 0.037 29.3 0.7133 1 0 0000 AA 10 57256.774856 NaN NaN NaN NaN NaN NaN  0.097389
# 40.125572 60.879280 0.0645 0.0599 -0.0223 12.840 0.028 38.7 1.5550 11.897 0.031 35.1 1.0450 1 0 0000 AA 5  57257.102751 NaN NaN NaN NaN NaN NaN  0.107707
# ...                                                                                                                                                   ...
# 40.125277 60.879341 0.1150 0.1078 -0.0397 13.511 0.041 26.2 1.2990 12.668 0.061 17.8 0.6642 1 0 0000 AA 5  57790.018946 NaN NaN NaN NaN NaN NaN  0.542346
# 40.125317 60.879219 0.1035 0.1091 -0.0272 13.328 0.038 28.6 1.8680 12.893 0.091 11.9 1.0750 1 0 0000 AA 5  57790.215429 NaN NaN NaN NaN NaN NaN  0.565899
# 40.125625 60.879152 0.1463 0.1293 -0.0575 13.734 0.048 22.9 0.9954 13.257 0.122 8.9  0.5377 1 0 0000 AB 5  57988.363121 NaN NaN NaN NaN NaN NaN  0.574875
# 40.125279 60.879235 0.1174 0.1057 -0.0497 13.360 0.049 22.3 0.7856 12.729 0.060 18.1 0.7291 1 0 0000 AA 5  57787.333756 NaN NaN NaN NaN NaN NaN  0.592270
# 40.126044 60.879185 0.1911 0.1661 -0.0549 14.036 0.070 15.4 4.3690 13.472 0.094 11.6 1.7010 1 0 0000 AA 0  57988.494025 NaN NaN NaN NaN NaN NaN  0.929713
#
#                                                                                                                                                       angle
# 40.125566 60.879306 0.0947 0.0936 -0.0337 13.251 0.038 28.8 0.8767 12.735 0.058 18.6 0.7135 1 0 0000 AA 10 57621.235014 NaN NaN NaN NaN NaN NaN  242.330013
# 40.125574 60.879297 0.0925 0.0874 -0.0397 13.241 0.036 30.0 1.2610 12.629 0.051 21.2 1.1210 1 0 0000 AA 5  57621.628106 NaN NaN NaN NaN NaN NaN  192.659014
# 40.125623 60.879318 0.0808 0.0794  0.0098 12.753 0.039 27.8 0.7640 11.901 0.034 32.0 1.0590 1 0 0000 AA 10 57063.798302 NaN NaN NaN NaN NaN NaN   69.867298
# 40.125553 60.879286 0.0663 0.0608 -0.0156 12.774 0.028 38.6 1.3610 11.935 0.037 29.3 0.7133 1 0 0000 AA 10 57256.774856 NaN NaN NaN NaN NaN NaN  209.287467
# 40.125572 60.879280 0.0645 0.0599 -0.0223 12.840 0.028 38.7 1.5550 11.897 0.031 35.1 1.0450 1 0 0000 AA 5  57257.102751 NaN NaN NaN NaN NaN NaN  187.006050
# ...                                                                                                                                                     ...
# 40.125277 60.879341 0.1150 0.1078 -0.0397 13.511 0.041 26.2 1.2990 12.668 0.061 17.8 0.6642 1 0 0000 AA 5  57790.018946 NaN NaN NaN NaN NaN NaN  281.913746
# 40.125317 60.879219 0.1035 0.1091 -0.0272 13.328 0.038 28.6 1.8680 12.893 0.091 11.9 1.0750 1 0 0000 AA 5  57790.215429 NaN NaN NaN NaN NaN NaN  234.448038
# 40.125625 60.879152 0.1463 0.1293 -0.0575 13.734 0.048 22.9 0.9954 13.257 0.122 8.9  0.5377 1 0 0000 AB 5  57988.363121 NaN NaN NaN NaN NaN NaN  172.170603
# 40.125279 60.879235 0.1174 0.1057 -0.0497 13.360 0.049 22.3 0.7856 12.729 0.060 18.1 0.7291 1 0 0000 AA 5  57787.333756 NaN NaN NaN NaN NaN NaN  242.957045
# 40.126044 60.879185 0.1911 0.1661 -0.0549 14.036 0.070 15.4 4.3690 13.472 0.094 11.6 1.7010 1 0 0000 AA 0  57988.494025 NaN NaN NaN NaN NaN NaN  119.074968
#
# [137 rows x 12 columns]

# %% [markdown]
# That pure python solution is a bit annoying as it requires a for loop with a break, and specific knowledge about how IRSA tables handler data headers (hence the use of `linenum + 4` for `skiprows`). Alternatively, one could  manipulate the data file to read in the data.

# %%
# 2nd solution - YOU DON'T NEED TO DO THIS

# %% [markdown]
# That truly wasn't all that better - as it required a bunch of clicks/text editor edits. (There are programs such as `sed` and `awk` that could be used to execute all the necessary edits from the command line, but that too is cumbersome and somewhat like the initial all `python` solution).
#
# If astronomers are creating data in a "standard" format, then it ought to be easy for other astronomers to access that data.

# %% [markdown]
# Fortunately, in this particular case, there is an easy solution - [`astropy Tables`](http://docs.astropy.org/en/stable/table/).
#
# IRSA tables are so commonly used throughout the community, that the folks at `astropy` have created a convenience method for all of us to read in tables created in that particular (unusual?) format.

# %% [markdown]
# **Problem 1b**
#
# Use [`Table.read()`](http://docs.astropy.org/en/stable/api/astropy.table.Table.html#astropy.table.Table.read) to read in `irsa_catalog_WISE_iPTF14jg_search_results.tbl` to an `astropy Table` object.

# %%
from astropy.table import Table

Table.read(irsa_tbl_filepath, format='ipac' )
# Out:
# <Table length=137>
#     ra        dec      sigra   sigdec sigradec  w1mpro w1sigmpro  w1snr  w1rchi2 ... j_m_2mass j_msig_2mass h_m_2mass h_msig_2mass k_m_2mass k_msig_2mass   dist     angle
#    deg        deg      arcsec  arcsec  arcsec    mag      mag                    ...    mag        mag         mag        mag         mag        mag       arcsec     deg
#  float64    float64   float64 float64 float64  float64  float64  float64 float64 ...  float64    float64     float64    float64     float64    float64    float64   float64
# ---------- ---------- ------- ------- -------- ------- --------- ------- ------- ... --------- ------------ --------- ------------ --------- ------------ -------- ----------
# 40.1255655 60.8793063  0.0947  0.0936  -0.0337  13.251     0.038    28.8  0.8767 ...        --           --        --           --        --           -- 0.028668 242.330013
#  40.125574  60.879297  0.0925  0.0874  -0.0397  13.241     0.036    30.0   1.261 ...        --           --        --           --        --           -- 0.048011 192.659014
# 40.1256226 60.8793176  0.0808  0.0794   0.0098  12.753     0.039    27.8   0.764 ...        --           --        --           --        --           -- 0.079498  69.867298
# 40.1255528 60.8792864  0.0663  0.0608  -0.0156  12.774     0.028    38.6   1.361 ...        --           --        --           --        --           -- 0.097389 209.287467
# 40.1255725 60.8792803  0.0645  0.0599  -0.0223   12.84     0.028    38.7   1.555 ...        --           --        --           --        --           -- 0.107707  187.00605
# 40.1255736 60.8792799  0.1164  0.1059   -0.039  13.587     0.041    26.4   1.647 ...        --           --        --           --        --           -- 0.108928 185.907602
# 40.1255644 60.8792744  0.0856   0.086   -0.031  13.198     0.035    31.2   1.725 ...        --           --        --           --        --           -- 0.131052 192.038104
# 40.1255517 60.8792713  0.0679  0.0685  -0.0218  12.807     0.028    38.8   1.466 ...        --           --        --           --        --           -- 0.147884 199.589209
# 40.1255718 60.8792687  0.1224  0.1104  -0.0547  13.496     0.044    24.6  0.9767 ...        --           --        --           --        --           -- 0.149378 185.518975
# 40.1256236 60.8792728  0.1107  0.0933  -0.0383  13.355     0.038    28.7   1.508 ...        --           --        --           --        --           --  0.15417 150.300579
# 40.1256406 60.8792778  0.0666  0.0631  -0.0228  12.774     0.027    39.6   1.482 ...        --           --        --           --        --           -- 0.157204 137.514297
# 40.1255571 60.8792668  0.1325  0.1156  -0.0264  13.743     0.044    24.5   1.162 ...        --           --        --           --        --           -- 0.160622 194.465237
# 40.1255835 60.8792651  0.1131  0.1036     0.01  13.452     0.041    26.4  0.6449 ...        --           --        --           --        --           -- 0.161765 177.827528
# 40.1256055 60.8792645  0.1104  0.1036  -0.0323  13.337     0.044    24.9   1.626 ...        --           --        --           --        --           -- 0.169772 164.744266
# 40.1255604 60.8792609  0.0691   0.069  -0.0223    12.8     0.028    38.9  0.9064 ...        --           --        --           --        --           -- 0.180061 190.993589
#  40.125555 60.8792608  0.0644  0.0651  -0.0135  12.726     0.029    37.8   1.324 ...        --           --        --           --        --           -- 0.182458 193.889599
#        ...        ...     ...     ...      ...     ...       ...     ...     ... ...       ...          ...       ...          ...       ...          ...      ...        ...
# 40.1254819 60.8792058  0.1017  0.1033  -0.0525  13.388     0.039    27.5   1.004 ...        --           --        --           --        --           -- 0.412617 204.615517
# 40.1255084 60.8792008  0.0595  0.0601  -0.0209  12.729     0.028    39.0   1.033 ...        --           --        --           --        --           -- 0.412651  197.69722
# 40.1254239 60.8792209  0.1131   0.103   -0.019  13.339     0.043    25.2   1.214 ...        --           --        --           --        --           -- 0.421518 220.450847
# 40.1255101 60.8791979  0.0688   0.066  -0.0268  12.827     0.029    36.9   1.146 ...        --           --        --           --        --           -- 0.421731  196.88055
# 40.1255504 60.8791936   0.125  0.1098  -0.0364  13.614     0.041    26.4   2.587 ...        --           --        --           --        --           -- 0.422235 187.054691
# 40.1254655 60.8792057  0.0295  0.0298   0.0088  10.848     0.017    62.8   6.484 ...        --           --        --           --        --           --   0.4257  208.11313
# 40.1255491 60.8791925  0.1361  0.1355   -0.062  13.705     0.049    22.3  0.6866 ...        --           --        --           --        --           -- 0.426454 187.293029
# 40.1253863 60.8792324  0.1362    0.12  -0.0418  13.803     0.049    22.3  0.7825 ...        --           --        --           --        --           -- 0.439544  230.53831
# 40.1254017 60.8792188  0.1756  0.1349  -0.0354  13.417      0.08    13.5   1.913 ...        --           --        --           --        --           -- 0.453174 223.574167
# 40.1254504 60.8791953   0.065  0.0627  -0.0236  12.829     0.031    35.0   2.803 ...        --           --        --           --        --           -- 0.471232 208.805123
# 40.1254195  60.879191  0.0736  0.0604  -0.0255  12.777     0.027    39.9  0.8821 ...        --           --        --           --        --           -- 0.512441 213.279623
# 40.1253594 60.8792163  0.0631  0.0675  -0.0093  12.791      0.03    36.6    1.13 ...        --           --        --           --        --           -- 0.512985 228.885562
# 40.1252771 60.8793411   0.115  0.1078  -0.0397  13.511     0.041    26.2   1.299 ...        --           --        --           --        --           -- 0.542346 281.913746
# 40.1253172 60.8792186  0.1035  0.1091  -0.0272  13.328     0.038    28.6   1.868 ...        --           --        --           --        --           -- 0.565899 234.448038
# 40.1256247 60.8791518  0.1463  0.1293  -0.0575  13.734     0.048    22.9  0.9954 ...        --           --        --           --        --           -- 0.574875 172.170603
# 40.1252789 60.8792352  0.1174  0.1057  -0.0497   13.36     0.049    22.3  0.7856 ...        --           --        --           --        --           --  0.59227 242.957045
# 40.1260438 60.8791845  0.1911  0.1661  -0.0549  14.036      0.07    15.4   4.369 ...        --           --        --           --        --           -- 0.929713 119.074968

# %% [markdown]
# A benefit to using this method, as opposed to `pandas`, is that data typing and data units are naturally read from the IRSA table and included with the associated columns. Thus, if you are uncertain if some brightness measurement is in magnitudes or Janskys, the `astropy Table` can report on that information.
#
# Unfortunately, `astropy` does *not* know about every strange formating decision that every astronomer has made at some point in their lives (as we are about to see...)

# %% [markdown]
# ## Problem 2) The Sins of Our Journals

# %% [markdown]
# Unlike IRSA/IPAC, which uses a weird but nevertheless consistent format for data tables, data retrieved from Journal articles essentially follows no rules. In principle, tables in Journal articles are supposed to be provided in a machine readable format. In practice, as we are about to see, this is far from the case.
#
# For this particular wrangling case study we will focus on supernova light curves, a simple thing to report: time, filter, brightness, uncertainty on that brightness, that the community has nevertheless managed to mangle into some truly wild and difficult to parse forms.

# %% [markdown]
# (Sorry for the heavy emphasis on time-domain examples - I'm pulling straight from my own life today, but the issues described here are not perfectly addressed by any subfield within the astro umbrella)

# %% [markdown]
# Here is the LaTeX-formatted version of Table 4 from [Miller et al. 2011](https://iopscience.iop.org/article/10.1088/0004-637X/730/2/80/meta):
#
# <img style="display: block; margin-left: auto; margin-right: auto" src="images/Miller11_tbl4.png" width="350" align="middle">

# %% [markdown]
# That is a very simple table to interpret, no?
#
# Have a look at the ["machine-readible" file](https://northwestern.box.com/s/o9nxkr3o79xunfo2o7r8nnas2sskncrc) that ApJ provides for readers that might want to evaluate these photometric measurements.

# %% [markdown]
# **Problem 2a**
#
# Read the ApJ version of Table 4 from from Miller et al. 2011 – called `Miller_et_al2011_table4.txt` – into either a `pandas DataFrame` or an `astropy Table`.

# %%
cat /Users/kylerocha/Private/data/dsfp_Session15_wrangling/Miller_et_al2011_table4.txt
# Out:
# Table 4
# PAIRITEL Observations of LkHalpha 188-G4
#
# t_mid^a	J mag	H mag	K_s mag
# (MJD)	(Vega)	(Vega)	(Vega)
# 55466.137	10.04 +or- 0.03	9.14 +or- 0.03	8.65 +or- 0.03
# 55468.145	9.99 +or- 0.03	9.06 +or- 0.04	8.64 +or- 0.04
# 55469.148	10.04 +or- 0.03	9.07 +or- 0.03	8.70 +or- 0.03
# 55479.109	10.11 +or- 0.03	9.11 +or- 0.03	8.63 +or- 0.04
# 55504.164	10.20 +or- 0.03	9.24 +or- 0.03	8.74 +or- 0.03
# 55513.195	10.29 +or- 0.03	9.34 +or- 0.03	8.79 +or- 0.03
# 55518.168	10.32 +or- 0.03	9.34 +or- 0.04	8.84 +or- 0.03
# 55527.117	10.35 +or- 0.03	9.40 +or- 0.03	8.89 +or- 0.03
# 55531.145	10.40 +or- 0.03	9.44 +or- 0.03	8.97 +or- 0.03
# 55543.066	10.45 +or- 0.03	9.48 +or- 0.04	9.06 +or- 0.04
#
# Note.
# a Midpoint between the first and last exposures in a single stacked image.

# %%
# read in the data from Miller et al 2011
base_path = '/Users/kylerocha/Private/data/dsfp_Session15_wrangling/'
pd.read_csv(base_path + 'Miller_et_al2011_table4.txt', skiprows=3, delimiter='\t')
# Out:
#                                               t_mid^a            J mag  \
# 0                                               (MJD)           (Vega)
# 1                                           55466.137  10.04 +or- 0.03
# 2                                           55468.145   9.99 +or- 0.03
# 3                                           55469.148  10.04 +or- 0.03
# 4                                           55479.109  10.11 +or- 0.03
# 5                                           55504.164  10.20 +or- 0.03
# 6                                           55513.195  10.29 +or- 0.03
# 7                                           55518.168  10.32 +or- 0.03
# 8                                           55527.117  10.35 +or- 0.03
# 9                                           55531.145  10.40 +or- 0.03
# 10                                          55543.066  10.45 +or- 0.03
# 11                                              Note.              NaN
# 12  a Midpoint between the first and last exposure...              NaN
#
#              H mag         K_s mag  Unnamed: 4
# 0           (Vega)          (Vega)         NaN
# 1   9.14 +or- 0.03  8.65 +or- 0.03         NaN
# 2   9.06 +or- 0.04  8.64 +or- 0.04         NaN
# 3   9.07 +or- 0.03  8.70 +or- 0.03         NaN
# 4   9.11 +or- 0.03  8.63 +or- 0.04         NaN
# 5   9.24 +or- 0.03  8.74 +or- 0.03         NaN
# 6   9.34 +or- 0.03  8.79 +or- 0.03         NaN
# 7   9.34 +or- 0.04  8.84 +or- 0.03         NaN
# 8   9.40 +or- 0.03  8.89 +or- 0.03         NaN
# 9   9.44 +or- 0.03  8.97 +or- 0.03         NaN
# 10  9.48 +or- 0.04  9.06 +or- 0.04         NaN
# 11             NaN             NaN         NaN
# 12             NaN             NaN         NaN

# %% [markdown]
# That wasn't too terrible. But what if we consider a more typical light curve table, where there are loads of missing data, such as Table 2 from [Foley et al. 2009](https://iopscience.iop.org/article/10.1088/0004-6256/138/2/376#aj309430t2):
#
# <img style="display: block; margin-left: auto; margin-right: auto" src="images/Foley09_tbl2.png" width="350" align="middle">

# %% [markdown]
# Again, this table is straightforward to read, and it isn't hard to imagine how one could construct a machine-readable csv or other file from this information. But alas, this is not what is available from ApJ. So, we will need to figure out how to deal with both the missing data, "...", and the weird convention that many astronomers use where the uncertainties are (a) not reported in their own column, and (b) are not provided in the same units as the measurement itself. I can understand the former, but the later is somewhat baffling...

# %% [markdown]
# **Problem 2b**
#
# Read the ApJ version of Table 2 from from Foley et al. 2009 – called `Foley_et_al2009_table2.txt` – into either a `pandas DataFrame` or an `astropy Table`.

# %%
cat /Users/kylerocha/Private/data/dsfp_Session15_wrangling/Foley_et_al2009_table2.txt
# Out:
# Table 2
# Lick Photometry of SN 2008ha
#
# JD	B (mag)	V (mag)	R (mag)	I (mag)	Unfiltered (mag)	Telescope
# 2454764.80	 sdotsdotsdot 	 sdotsdotsdot 	 sdotsdotsdot 	 sdotsdotsdot 	>19.5	KAIT
# 2454778.69	 sdotsdotsdot 	 sdotsdotsdot 	 sdotsdotsdot 	 sdotsdotsdot 	18.069 (092)	KAIT
# 2454781.76	18.340 (084)	17.828 (037)	 sdotsdotsdot 	 sdotsdotsdot 	 sdotsdotsdot 	KAIT
# 2454783.74	18.229 (062)	17.718 (042)	17.509 (041)	17.377 (054)	 sdotsdotsdot 	KAIT
# 2454784.64	 sdotsdotsdot 	 sdotsdotsdot 	 sdotsdotsdot 	 sdotsdotsdot 	17.736 (091)	KAIT
# 2454784.71	18.230 (030)	17.635 (030)	17.570 (030)	17.392 (030)	 sdotsdotsdot 	Nickel
# 2454785.67	18.385 (030)	17.660 (027)	17.610 (023)	17.425 (034)	17.683 (038)	KAIT
# 2454786.80	18.415 (030)	17.710 (030)	17.544 (030)	17.358 (030)	 sdotsdotsdot 	Nickel
# 2454787.67	18.596 (030)	17.762 (030)	17.552 (030)	17.376 (030)	 sdotsdotsdot 	KAIT
# 2454789.68	18.904 (030)	17.827 (014)	17.573 (011)	17.353 (030)	17.732 (028)	KAIT
# 2454790.71	18.969 (030)	17.871 (030)	17.560 (030)	17.278 (030)	 sdotsdotsdot 	Nickel
# 2454792.70	19.563 (054)	18.127 (022)	17.689 (016)	17.443 (030)	 sdotsdotsdot 	KAIT
# 2454794.68	19.789 (072)	18.377 (032)	17.904 (025)	17.541 (037)	 sdotsdotsdot 	KAIT
# 2454795.78	20.297 (216)	 sdotsdotsdot 	 sdotsdotsdot 	 sdotsdotsdot 	18.009 (103)	KAIT
# 2454798.65	20.390 (123)	18.791 (033)	18.308 (022)	17.876 (039)	18.388 (022)	KAIT
# 2454799.66	 sdotsdotsdot 	18.921 (046)	18.343 (029)	17.919 (050)	18.468 (040)	KAIT
# 2454800.67	 sdotsdotsdot 	18.942 (035)	18.347 (029)	17.892 (033)	18.482 (027)	KAIT
# 2454801.64	 sdotsdotsdot 	19.004 (044)	18.438 (026)	17.964 (036)	18.589 (031)	KAIT
# 2454802.74	 sdotsdotsdot 	19.064 (082)	18.472 (037)	17.921 (030)	18.635 (026)	KAIT
# 2454803.63	 sdotsdotsdot 	19.130 (054)	18.569 (031)	18.087 (047)	18.589 (030)	KAIT
# 2454805.63	 sdotsdotsdot 	19.211 (095)	18.851 (055)	18.142 (056)	18.682 (048)	KAIT
# 2454809.67	 sdotsdotsdot 	19.288 (206)	19.104 (135)	 sdotsdotsdot 	18.909 (078)	KAIT
# 2454811.61	 sdotsdotsdot 	19.462 (103)	19.069 (073)	18.374 (067)	19.150 (060)	KAIT
# 2454812.62	 sdotsdotsdot 	19.458 (207)	19.118 (065)	18.482 (077)	19.070 (049)	KAIT
# 2454831.63	21.372 (030)	20.191 (030)	19.647 (030)	18.864 (030)	 sdotsdotsdot 	Nickel
#
# Note. Uncertainties (units of 0.001 mag) are given in parentheses.

# %%
# read in the data from Foley et al 2009
base_path = '/Users/kylerocha/Private/data/dsfp_Session15_wrangling/'
pd.read_csv(base_path + 'Foley_et_al2009_table2.txt', skiprows=3, delimiter='\t')
# Out:
#                                                    JD         B (mag)  \
# 0                                          2454764.80   sdotsdotsdot
# 1                                          2454778.69   sdotsdotsdot
# 2                                          2454781.76    18.340 (084)
# 3                                          2454783.74    18.229 (062)
# 4                                          2454784.64   sdotsdotsdot
# 5                                          2454784.71    18.230 (030)
# 6                                          2454785.67    18.385 (030)
# 7                                          2454786.80    18.415 (030)
# 8                                          2454787.67    18.596 (030)
# 9                                          2454789.68    18.904 (030)
# 10                                         2454790.71    18.969 (030)
# 11                                         2454792.70    19.563 (054)
# 12                                         2454794.68    19.789 (072)
# 13                                         2454795.78    20.297 (216)
# 14                                         2454798.65    20.390 (123)
# 15                                         2454799.66   sdotsdotsdot
# 16                                         2454800.67   sdotsdotsdot
# 17                                         2454801.64   sdotsdotsdot
# 18                                         2454802.74   sdotsdotsdot
# 19                                         2454803.63   sdotsdotsdot
# 20                                         2454805.63   sdotsdotsdot
# 21                                         2454809.67   sdotsdotsdot
# 22                                         2454811.61   sdotsdotsdot
# 23                                         2454812.62   sdotsdotsdot
# 24                                         2454831.63    21.372 (030)
# 25  Note. Uncertainties (units of 0.001 mag) are g...             NaN
#
#            V (mag)         R (mag)         I (mag) Unfiltered (mag) Telescope  \
# 0    sdotsdotsdot    sdotsdotsdot    sdotsdotsdot             >19.5      KAIT
# 1    sdotsdotsdot    sdotsdotsdot    sdotsdotsdot      18.069 (092)      KAIT
# 2     17.828 (037)   sdotsdotsdot    sdotsdotsdot     sdotsdotsdot       KAIT
# 3     17.718 (042)    17.509 (041)    17.377 (054)    sdotsdotsdot       KAIT
# 4    sdotsdotsdot    sdotsdotsdot    sdotsdotsdot      17.736 (091)      KAIT
# 5     17.635 (030)    17.570 (030)    17.392 (030)    sdotsdotsdot     Nickel
# 6     17.660 (027)    17.610 (023)    17.425 (034)     17.683 (038)      KAIT
# 7     17.710 (030)    17.544 (030)    17.358 (030)    sdotsdotsdot     Nickel
# 8     17.762 (030)    17.552 (030)    17.376 (030)    sdotsdotsdot       KAIT
# 9     17.827 (014)    17.573 (011)    17.353 (030)     17.732 (028)      KAIT
# 10    17.871 (030)    17.560 (030)    17.278 (030)    sdotsdotsdot     Nickel
# 11    18.127 (022)    17.689 (016)    17.443 (030)    sdotsdotsdot       KAIT
# 12    18.377 (032)    17.904 (025)    17.541 (037)    sdotsdotsdot       KAIT
# 13   sdotsdotsdot    sdotsdotsdot    sdotsdotsdot      18.009 (103)      KAIT
# 14    18.791 (033)    18.308 (022)    17.876 (039)     18.388 (022)      KAIT
# 15    18.921 (046)    18.343 (029)    17.919 (050)     18.468 (040)      KAIT
# 16    18.942 (035)    18.347 (029)    17.892 (033)     18.482 (027)      KAIT
# 17    19.004 (044)    18.438 (026)    17.964 (036)     18.589 (031)      KAIT
# 18    19.064 (082)    18.472 (037)    17.921 (030)     18.635 (026)      KAIT
# 19    19.130 (054)    18.569 (031)    18.087 (047)     18.589 (030)      KAIT
# 20    19.211 (095)    18.851 (055)    18.142 (056)     18.682 (048)      KAIT
# 21    19.288 (206)    19.104 (135)   sdotsdotsdot      18.909 (078)      KAIT
# 22    19.462 (103)    19.069 (073)    18.374 (067)     19.150 (060)      KAIT
# 23    19.458 (207)    19.118 (065)    18.482 (077)     19.070 (049)      KAIT
# 24    20.191 (030)    19.647 (030)    18.864 (030)    sdotsdotsdot     Nickel
# 25             NaN             NaN             NaN              NaN       NaN
#
#     Unnamed: 7
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN

# %% [markdown]
# Okay - there is nothing elegant about that particular solution. But it works, and wranglin' ain't pretty.
#
# It is likely that you developed a solution that looks very different from this one, and that is fine. When data are provided in an unrulely format, the most important thing is to develop some method, any method, for converting the information into a useful format. Following whatever path you used above, it should now be easy to plot the light curve of SN 2008ha.

# %% [markdown]
# ## Problem 3) My Heart Will Go On
#
# Sometimes there is no difficultly whatsoever in reading in the data (as was the case in **Problems 1** and **2**), but instead the difficultly lies in wranglin' the data to be appropriate for the model that you are building.
#
# For the next problem we will work with the famous [Titanic survival](https://www.kaggle.com/c/titanic/data?) data set.

# %% [markdown]
# Briefly, [the Titantic](https://thefilmcricket.files.wordpress.com/2012/04/film-titanic_clar.jpg) is a [famous](https://wallpapercave.com/wp/jrF8rQK.jpg) historical ship that was thought to be unsinkable. **Spoiler alert** it hit an iceberg and sank. The data in the Titanic data set includes information about 891 passengers from the Titanic, as well as whether or not they survived. The aim of this data set is to build a machine learning model to predict which passengers survived and which did not.

# %% [markdown]
# The features include:
#
# |Feature    | Description |
# |:---------:|:--------------------------------------:|
# |PassengerId| Running index that describes the individual passengers|
# |Pclass| A proxy for socio-economic status (1 = Upper class, 2 = Middle Class, 3 = Lower Class)|
# |Name| The passenger's name|
# |Sex | The passenger's sex|
# |Age | The passenger's age - note age's ending in 0.5 are estimated |
# |SibSp| The sum of the passenger's sibblings and spouces on board|
# |Parch| The sum of the passenger's parents and children on board|
# |Ticket| The ticket number for the passenger|
# |Fare| The price paid for the ticket by th passenger|
# |Cabin| The Cabin in which the passenger stayed|
# |Embarked| The point of Origin for the Passenger: C = Cherbourg, S = Southampton, Q = Queenstown|

# %% [markdown]
# And of course, we are trying to predict:
#
# |Label    | Description |
# |:---------:|:--------------------------------------:|
# |Survived| 1 = yes; 0 = no|

# %% [markdown]
# **Problem 3a**
#
# Read in the Titanic training data and create the `scikit-learn` standard `X` and `y` arrays to hold the features and the labels, respectively.

# %%
ls /Users/kylerocha/Private/data/dsfp_Session15_wrangling/
# Out:
# DSFP_SDSS_spec_train.csv
# Foley_et_al2009_table2.txt
# Miller_et_al2011_table4.txt
# irsa_catalog_WISE_iPTF14jg_search_results.tbl
# titanic_kaggle_training_set.csv

# %%
titanic_df = pd.read_csv( base_path + 'titanic_kaggle_training_set.csv' )

print(len(titanic_df))

feat_list = list(titanic_df.columns)
label = 'Survived'
feat_list.remove(label)

feat_list.remove('Name') # we have passenger ID so we can remove this
feat_list.remove('Ticket') # 681 unique tickets, largest repeat has 7 occurances so drop instead of using one hot
feat_list.remove('Cabin') # 147 unique cabins, largest repeat has 4 occurances so drop instead of using one hot

feat_list.remove('Embarked') # just move on
feat_list.remove('Sex')
feat_list.remove('PassengerId')

where_age_isnotnan = np.logical_not( np.isnan( titanic_df['Age'] ) )
titanic_df = titanic_df.loc[where_age_isnotnan]

X = titanic_df[ feat_list ]
y = titanic_df[label]

# encode_Embarked = pd.get_dummies( titanic_df['Embarked'] )
# X = X.append( encode_Embarked , ignore_index=True)
    
X
# Out:
# 891
#      Pclass   Age  SibSp  Parch     Fare
# 0         3  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         3  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         3  35.0      0      0   8.0500
# ..      ...   ...    ...    ...      ...
# 885       3  39.0      0      5  29.1250
# 886       2  27.0      0      0  13.0000
# 887       1  19.0      0      0  30.0000
# 889       1  26.0      0      0  30.0000
# 890       3  32.0      0      0   7.7500
#
# [714 rows x 5 columns]

# %% [markdown]
# Now that we have the data in the appropriate `X` and `y` arrays, estimate the accuracy with which a [K nearest neighbors](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html) classification model can predict whether or not a passenger would survive the Titanic disaster. Use $k=10$ fold cross validation for the prediction.

# %% [markdown]
# **Problem 3b**
#
# Train a $k=7$ nearest neighbors machine learning model on the Titanic training set.

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier( n_neighbors=7)
knn_clf.fit( X.values, y.values )
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %% [markdown]
# Note - that should have failed! And for good reason - recall that `kNN` models measure the Euclidean distance between all points within the feature space. So, when considering the sex of a passenger, what is the *numerical* distance between male and female?

# %% [markdown]
# In other words, we need to wrangle this data before we can run the machine learning model.
#
# Most of the features in this problem are non-numeric (i.e. we are dealing with categorical features), and therefore we need to figure out how to include them in the `kNN` model.

# %% [markdown]
# The first step when wrangling for machine learning is to figure out if anything can be thrown away. We certainly want to avoid including any uninformative features in the model.
#
# *If you haven't already, now would be a good time to create a new cell and examine the contents of the csv*

# %%
titanic_df
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 885         886         0       3
# 886         887         0       2
# 887         888         1       1
# 889         890         1       1
# 890         891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [714 rows x 12 columns]

# %% [markdown]
# **Problem 3c**
#
# Are there any features that *obviously* will not help with this classification problem?
#
# *If you answer yes - ignore those features moving forward*

# %% [markdown]
# **Solution 3c**
#
# *write your solution here*

# %% [markdown]
# Given that we have both categorical and numeric features, let's start with the numerical features and see how well they can predict survival on the Titanic.
#
# One note - for now we are going to exclude `Age`, because as you saw when you examined the data, there are some passengers that do not have any age information. This problem, known as "missing data" is one that we will deal with before the end of this problem.

# %% [markdown]
# **Problem 3d**
#
# How accurately can the numeric features, `Pclass`, `SibSp`, `Parch`, and `Fare` predict survival on the Titanic? Use a $k = 7$ Nearest Neighbors model, and estimate the model accuracy using 10-fold cross validation.
#
# *Hint 1 - you'll want to redefine your features vector `X`*
#
# *Hint 2 - you may find [`cross_val_score`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html) from `scikit-learn` helpful*

# %%
from sklearn.model_selection import cross_val_score

knn_clf = KNeighborsClassifier( n_neighbors=7)
knn_clf.fit( X.values, y.values )
cv_results = cross_val_score( knn_clf, X, y)

print('The accuracy from numeric features = {:.2f}%'.format(100*np.mean(cv_results)))
# Out:
# The accuracy from numeric features = 67.10%

# %%
X.columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %% [markdown]
# An accuracy of 68% isn't particularly inspiring. But, there's a lot of important information that we are excluding. As far as the Titanic is concerned, Kate and Leo taught us that [female passengers are far more likely to survive](https://qph.fs.quoracdn.net/main-qimg-93eb36091c7eec872b891fa51dc5722b), while [male passengers are not](http://hoycinema.abc.es/Media/201602/03/titanic-kate-dicaprio--644x362.jpg). So, if we can include gender in the model then we may be able to achieve more accurate predictions.

# %% [markdown]
# **Problem 3e**
#
# Create a new feature called `gender` that equals 1 for male passengers and 2 for female passengers. Add this feature to your dataframe, and include it in a `kNN` model with the other numeric features. Does the inclusion of this feature improve the 10-fold CV accuracy?

# %%
gender = np.where( titanic_df['Sex'] == 'male', 1,2 )
# complete

X['Gender'] = gender

knn_clf2 = KNeighborsClassifier(n_neighbors=7)
knn_clf2.fit( X.values, y.values )

cv_results = cross_val_score( knn_clf2, X, y)

print('The accuracy when including gender = {:.2f}%'.format(100*np.mean(cv_results)))
# Out:
# The accuracy when including gender = 68.22%
# /var/folders/j2/tlw62j517hb6ch7m280c_66h0000gn/T/ipykernel_8664/1914956805.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['Gender'] = gender

# %% [markdown]
# A 14% improvement is pretty good! But, we can wrangle even more out of the gender feature. Recall that `kNN` models measure the Euclidean distance between sources, meaning the scale of each feature really matters. Given that the fare ranges from 0 up to 512.3292, the `kNN` model will see this feature as far more important than `gender`, for no other reason than the units that have been adopted.
#
# If women are far more likely to survive than men, then we want to be sure that gender is weighted at least the same as all the other features, which we can do with a minmax scaler. As a brief reminder - a minmax scaler scales all values of a feature to be between 0 and 1 by subtracting the minimum value of each feature and then dividing by the maximum minus the minimum.

# %% [markdown]
# **Problem 3f**
#
# Scale all the features from the previous problem using a minmax scaler and evaluate the CV accuracy of the `kNN` model.
#
# *Hint - you may find [`MinMaxScaler`](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html) helpful*

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X)
Xminmax = scaler.transform(X)

knn_clf = # complete

cv_results = cross_val_score( # complete

print('The accuracy when scaling features = {:.2f}%'.format(100*np.mean(cv_results)))
# Out:
#   File "/var/folders/j2/tlw62j517hb6ch7m280c_66h0000gn/T/ipykernel_8664/844305864.py", line 7
#     knn_clf = # complete
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# Scaling the features leads to further improvement!
#
# Now turn your attention to another categorical feature, `Embarked`, which includes the point of origin for each passenger and has three categories, `S`, `Q`, and `C`. We need to convert these values to a numeric representation for inclusion in the model.

# %% [markdown]
# **Problem 3g**
#
# Convert the categorical feature `Embarked` to a numeric representation, and add it to the `titanic_df`.

# %%
# following previous example, set C = 0, S = 1, Q = 2

porigin = # complete
# complete
# complete
# complete

titanic_df['porigin'] = porigin

# %% [markdown]
# But wait! Does this actually make sense?
#
# Our "numerification" has now introduced order where there previously was none. We are effectively telling the model that Cherbourg and Queenstown are far apart (not in distance but in terms of the similarity of the passengers that boarded the ship in each location), while each are equally close to Southampton. Is there actually any evidence to support this conclusion?

# %% [markdown]
# By definition categorical features do not have order (e.g., cat, dog, horse, elephant), and therefore we should not impose any when converting these features to numeric values for inclusion in our model. Instead, we should be creating a new set of binary features for every category within the feature set. Thus, `Embarked` will now need to be represented by 3 different features, where the feature `Queenstown` equals one for passengers that boarded there and zero for everyone else.

# %% [markdown]
# **Problem 3h**
#
# Complete the function below that will automatically create binary arrays for a categorical feature.

# %%
def create_bin_cat_feats(feature_array):
    categories = np.unique(feature_array)
    feat_dict = {}
    for cat in categories:
        # complete
        # complete
        # complete
    return feat_dict

# %% [markdown]
# **Problem 3i**
#
# Use the `create_bin_cat_feats` function to convert the `Embarked` and `Sex` categorical features to a numeric representation (yes we need to do this for `Sex` as well where we otherwise previously introduced order). Add these features to the `titanic_df` data frame.

# %%
gender_dict = create_bin_cat_feats( # complete
porigin_dict = create_bin_cat_feats( # complete

for feat in gender_dict.keys():
    titanic_df[feat] = gender_dict[feat]
    
for feat in porigin_dict.keys():
    titanic_df[feat] = porigin_dict[feat]

# %% [markdown]
# **Problem 3j**
#
# Use the newly created `female`, `male`, `S`, `Q`, and `C` features in combination with the `Pclass`, `SibSp`, `Parch`, and `Fare` features to estimate the classification accuracy of a $k = 7$ nearest neighbors model with 10-fold cross validation.
#
# How does the addition of the point of origin feature affect the final model output?
#
# *Hint - don't forget to scale the features in the model*

# %%
from sklearn.preprocessing import MinMaxScaler

X = # complete

scaler = MinMaxScaler()
scaler.fit(X)
Xminmax = scaler.transform(X)

cv_results = cross_val_score( # complete

print('The accuracy with categorical features = {:.2f}%'.format(100*np.mean(cv_results)))

# %% [markdown]
# The last thing we'd like to add to the model is the `Age` feature. Unfortunately, for 177 passengers we do not have a reported value for their age. This is a standard issue when building models known as "missing data" and this happens in astronomy all the time (for example, LSST is going to observe millions of L and T dwarfs that are easily detected in the $y$-band, but which will not have a detection in $u$-band).

# %% [markdown]
# There are several different strategies for dealing with missing data. The first and most straightforward is to simply remove observations with missing data (note - to simplify this example I already did this by removing the 2 passengers from the training set that did not have an entry for `Embarked`).
#
# This strategy is perfectly fine if only a few sources have missing information (2/891 for `Embarked` - and none of the test set sources are missing `Embarked`). If, however, a significant fraction are missing data, this strategy would remove a lot of useful data from the model.

# %% [markdown]
# If you cannot remove the sources with missing data, then it is essential to ask the following question:
#
# Does the missing information have meaning?
#
# In the LSST L/T dwarf example, the lack of a $u$-band detection is meaningful: these stars are too faint for LSST. When this is the case, an indicator value (e.g., -999) allows the model to recognize the non-detection.

# %% [markdown]
# For the Titanic data, the lack of age information is not meaningful. Simply put, there are some passengers that did not have recorded ages. We will now show this to be the case.

# %% [markdown]
# **Problem 3k**
#
# Replace the unknown ages with a value of -999, and estimate the accuracy of the model via 10-fold cross validation.

# %%
age_impute = # complete
# complete

titanic_df['age_impute'] = age_impute

X = # complete

scaler = MinMaxScaler()
scaler.fit(X)
Xminmax = scaler.transform(X)

cv_results = cross_val_score( # complete

print('The accuracy with -999 for missing ages = {:.2f}%'.format(100*np.mean(cv_results)))

# %% [markdown]
# The accuracy of the model hasn't improved by adding the age information (even though we know children were more likely to survive than adults).
#
# Given that the missing ages don't have meaning, we need to develop alternative strategies for "imputing" the missing data. The most simple approach in this regard is to replace the missing values with the mean value of the feature distribution for sources that do have measurements (use the median if the distribution has significant outliers).

# %% [markdown]
# **Problem 3l**
#
# Replace the unknown ages with the mean age of passengers, and estiamte the accuracy of the model via 10-fold cross validation.

# %%
age_impute = # complete
# complete

titanic_df['age_impute'] = age_impute

X = # complete

scaler = MinMaxScaler()
scaler.fit(X)
Xminmax = scaler.transform(X)

cv_results = cross_val_score( # complete

print('The accuracy with the mean for missing ages = {:.2f}%'.format(100*np.mean(cv_results)))

# %% [markdown]
# Using the mean age for missing values provides a marginal improvement over the models with no age information. Is there anything else we can do? Yes - we can build a machine learning model to predict the values of the missing data. So there will be a machine learning model within the final machine learning model. In order to predict ages, we will need to build a regression model. Simple algorithms include Linear or Logistic Regression, while more complex examples include `kNN` or random forest regression.
#
# I quickly tested the above four methods, and found that the `scikit-learn` [`LinearRegression`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression) performs best when using the model defaults.

# %% [markdown]
# **Problem 3m**
#
# Build a `LinearRegression` model to predict a passenger's age based on the `Pclass`, `SibSp`, `Parch`, `Fare`, `female`, `male`, `S`, `Q`, `C` features. The model should be trained with passengers that have known ages. Use 10-fold cross validation to determine the performance of this model.
#
# *Hint - note that for regression models the typical metric of evaluation is the [mean squared error](https://en.wikipedia.org/wiki/Mean_squared_error), and that for consistency within the `scikit-learn` API, the [negative mean squared error is returned rather than the mean squared error](https://scikit-learn.org/stable/modules/model_evaluation.html#common-cases-predefined-values).*

# %%
from sklearn.linear_model import LinearRegression

has_ages = np.where(np.isfinite(titanic_df['Age']))[0]

impute_X_train = # complete
impute_y_train = # complete

scaler = MinMaxScaler()
scaler.fit(impute_X_train)
Xminmax = scaler.transform(impute_X_train)

lr_age = LinearRegression().fit( # complete

cv_results = cross_val_score(LinearRegression(), Xminmax, impute_y_train, cv=10, scoring='neg_mean_squared_error')

print('Missing ages have RMSE = {:.2f}'.format(np.mean((-1*cv_results)**0.5)))

# %% [markdown]
# **Problem 3n**
#
# Use the age regression model to predict the ages for passengers with missing data.

# %%
missing_ages = np.where(np.isnan(titanic_df['Age']))[0]

impute_X_missing = # complete

X_missing_minmax = scaler.transform(impute_X_missing)

age_preds = lr_age.predict(X_missing_minmax)

# %% [markdown]
# **Problem 3o**
#
# Use the imputed age estimates to predict the passenger survival via 10-fold cross validation.

# %%
age_impute = titanic_df['Age'].copy().values
age_impute[missing_ages] = # complete

titanic_df['age_impute'] = age_impute

X = # complete

scaler = MinMaxScaler()
scaler.fit(X)
Xminmax = scaler.transform(X)

cv_results = cross_val_score( # complete

print('The accuracy with the mean for missing ages = {:.2f}%'.format(100*np.mean(cv_results)))

# %% [markdown]
# As far as ages are concerned, imputation of the missing data does not significantly improve the model.
#
# Which brings us to the concluding lesson in wrangling the Titanic data - not every piece of information is *useful*. This is critical to remember when building machine learning models.

# %% [markdown]
# (As a quick aside - it wouldn't be entirely fair to say there is no useful information in the age feature. It is clear, for example, that "children," i.e. those with Age < 10, had a much higher probability of survival than adults. Perhaps the creation of a `child` feature based on age would improve the model... or using the age in combination with other features, e.g., `Age`x`Pclass` which will further highlight that 1st class passengers were more likely to survive than 3rd class passengers)

# %% [markdown]
# Finally - note that you can try to build a model and submit it to Kaggle to see how well you preform on blind data.
#
# https://www.kaggle.com/c/titanic - the classifications are not revealed, but from the [leaderboard](https://www.kaggle.com/c/titanic/leaderboard) it is clear that some people were able to build models that perfectly classified the blind data.

# %% [markdown]
# ## Problem 4) Wrangling an astro machine learning model

# %% [markdown]
# Now we will put together the above examples to work on an astronomical problem of great importance for LSST: photometric redshifts. As we have previously discussed, LSST will observe many, many, many, many more galaxies than we can possibly observe with spectroscopic instruments. As a result, the vast majority of the galaxies observed by LSST will not have precise redshift estimates, and instead we will need to estimate redshifts via photometry alone.

# %% [markdown]
# This week we have heard a lot about `SDSS CasJobs`, and for today's problem we will use 50,000 SDSS sources with spectroscopic measurements to train a machine learning model to estimate redshifts from photometry. The following query was used to generate this training set:
#
#     select top 50000 s.specObjID, s.z, s.type,
#        psfMag_u, psfMag_g, psfMag_r, psfMag_i, psfMag_z,
#        modelMag_u, modelMag_g, modelMag_r, modelMag_i, modelMag_z,
#        extinction_u, extinction_g, extinction_r, extinction_i, extinction_z,
#        w.w1mpro, w1snr, w.w2mpro, w2snr, w.w3mpro, w3snr, w.w4mpro, w4snr
#        from specphotoall s
#          join (WISE_xmatch wx
#            join WISE_allsky w on wx.wise_cntr = w.cntr) on s.objid = wx.sdss_objid

# %% [markdown]
# A few notes about the data: `specObjID` is the SDSS identifier, `z` is the redshift, `type` is the photometric type ("ps" for point source or "ext" for extended), `psfMag` is the SDSS PSF mag in each filter, `modelMag` is the aperture-matched model mag in each filter, `extinction` is the SFD extinction estimate, `w?mpro` is the [WISE](https://www.nasa.gov/mission_pages/WISE/main/index.html) satellite mid-IR magnitude in the W1, W2, W3, and W4 bands, and `w?msnr` is the SNR in each of the respective filters.

# %% [markdown]
# *quick aside* - the SDSS photometric type is reported as either 6 or 3, and, for convenience, I have converted these to 'ps' and 'ext' in the file used for the problem below.

# %% [markdown]
# **Important note** - not every SDSS source will have detections in each of the WISE filters. If `w?msnr` < 2, then the `w?mpro` number represents an upper limit, *not* a detection (i.e., these are cases with missing data).

# %% [markdown]
# **Problem 4a**
#
# Read the SDSS training set data – in a file called `DSFP_SDSS_spec_train.csv` – into either a `pandas` DataFrame or `astropy` Table.

# %%
sdss = pd.read_csv(base_path + "DSFP_SDSS_spec_train.csv")
sdss.head()
# Out:
#             specObjID         z type  psfMag_u  psfMag_g  psfMag_r  psfMag_i  \
# 0  299567742770505728  0.071414  ext  20.88291  19.23907  18.56170  18.09715
# 1  299568017178650624  0.071380  ext  20.88291  19.23907  18.56170  18.09715
# 2  299566643258877952  0.088173  ext  20.84844  18.96040  18.08027  17.62953
# 3  299569116690278400  0.088161  ext  20.84844  18.96040  18.08027  17.62953
# 4  299568292056557568  0.066539  ext  21.28256  19.61427  18.98529  18.52956
#
#    psfMag_z  modelMag_u  modelMag_g  ...  extinction_i  extinction_z  w1mpro  \
# 0  17.76469    19.62189    18.03702  ...      0.061267      0.045572  14.395
# 1  17.76469    19.62189    18.03702  ...      0.061267      0.045572  14.395
# 2  17.31857    20.18508    18.26120  ...      0.047582      0.035392  14.162
# 3  17.31857    20.18508    18.26120  ...      0.047582      0.035392  14.162
# 4  18.26322    20.18081    18.47435  ...      0.058709      0.043669  14.734
#
#    w1snr  w2mpro  w2snr  w3mpro  w3snr  w4mpro  w4snr
# 0   21.1  14.236   15.6  11.029    6.8   8.579   -0.9
# 1   21.1  14.236   15.6  11.029    6.8   8.579   -0.9
# 2   35.0  13.970   22.3  12.233    2.9   9.067   -0.3
# 3   35.0  13.970   22.3  12.233    2.9   9.067   -0.3
# 4   30.6  14.512   17.6  11.078    9.8   9.054    2.3
#
# [5 rows x 26 columns]

# %% [markdown]
# **Problem 4b**
#
# Are there categorical features in the dataset? If yes, convert the categorical features for use in machine learning models.
#
# *Hint* - recall **Problem 3h** and **3i**.

# %%
sdss.iloc[7]
# Out:
# specObjID       299568842282133504
# z                         0.090671
# type                           ext
# psfMag_u                  21.25095
# psfMag_g                  20.01011
# psfMag_r                  19.44431
# psfMag_i                  19.01693
# psfMag_z                   18.7417
# modelMag_u                19.41755
# modelMag_g                18.08171
# modelMag_r                17.46448
# modelMag_i                 17.0903
# modelMag_z                16.86987
# extinction_u              0.119282
# extinction_g              0.092944
# extinction_r              0.064298
# extinction_i               0.04778
# extinction_z               0.03554
# w1mpro                      14.881
# w1snr                         28.2
# w2mpro                       14.62
# w2snr                         15.5
# w3mpro                      11.071
# w3snr                          8.2
# w4mpro                       8.838
# w4snr                          0.4
# Name: 7, dtype: object

# %%
onehot = pd.get_dummies( sdss['type'] )

sdss = pd.concat( [sdss, onehot], axis=1 )

sdss
# Out:
#                 specObjID         z type  psfMag_u  psfMag_g  psfMag_r  \
# 0      299567742770505728  0.071414  ext  20.88291  19.23907  18.56170
# 1      299568017178650624  0.071380  ext  20.88291  19.23907  18.56170
# 2      299566643258877952  0.088173  ext  20.84844  18.96040  18.08027
# 3      299569116690278400  0.088161  ext  20.84844  18.96040  18.08027
# 4      299568292056557568  0.066539  ext  21.28256  19.61427  18.98529
# ...                   ...       ...  ...       ...       ...       ...
# 49995  427910439263823872  0.122827  ext  22.04694  19.90851  18.95757
# 49996  427913462920800256  0.259755  ext  21.49931  20.45282  19.28250
# 49997  427892022444058624 -0.000071   ps  23.55219  21.35737  19.77218
# 49998  427901368292894720 -0.000028   ps  23.72416  24.05965  22.91600
# 49999  427902467804522496  0.241652  ext  21.18222  20.29527  19.72853
#
#        psfMag_i  psfMag_z  modelMag_u  modelMag_g  ...  w1mpro  w1snr  w2mpro  \
# 0      18.09715  17.76469    19.62189    18.03702  ...  14.395   21.1  14.236
# 1      18.09715  17.76469    19.62189    18.03702  ...  14.395   21.1  14.236
# 2      17.62953  17.31857    20.18508    18.26120  ...  14.162   35.0  13.970
# 3      17.62953  17.31857    20.18508    18.26120  ...  14.162   35.0  13.970
# 4      18.52956  18.26322    20.18081    18.47435  ...  14.734   30.6  14.512
# ...         ...       ...         ...         ...  ...     ...    ...     ...
# 49995  18.66708  18.18741    20.41257    18.49640  ...  14.575   30.4  14.397
# 49996  18.89629  18.41247    20.96373    19.73372  ...  14.745   27.6  14.481
# 49997  18.17955  17.30377    23.69296    21.35464  ...  14.736   29.4  14.634
# 49998  19.86693  18.24050    23.62215    24.03528  ...  14.893   27.0  14.675
# 49999  19.50787  19.08041    20.62539    19.67341  ...  15.449   22.0  14.786
#
#        w2snr  w3mpro  w3snr  w4mpro  w4snr  ext  ps
# 0       15.6  11.029    6.8   8.579   -0.9    1   0
# 1       15.6  11.029    6.8   8.579   -0.9    1   0
# 2       22.3  12.233    2.9   9.067   -0.3    1   0
# 3       22.3  12.233    2.9   9.067   -0.3    1   0
# 4       17.6  11.078    9.8   9.054    2.3    1   0
# ...      ...     ...    ...     ...    ...  ...  ..
# 49995   17.9  11.974    1.8   8.954    0.3    1   0
# 49996   16.3  12.616   -1.5   8.986   -1.6    1   0
# 49997   14.5  11.924    1.9   9.045   -1.1    0   1
# 49998   14.2  11.931    2.0   9.153   -0.8    0   1
# 49999   13.3  10.709   11.7   8.771    2.7    1   0
#
# [50000 rows x 28 columns]

# %% [markdown]
# **Problem 4c**
#
# Is there missing data in the training set? If yes, how will you deal these data?
#
# *Hint* - you were already told there is missing data.

# %%
sdss = sdss.drop(columns=['type'])

# %%
# WISE non-detections have SNR < 2

for col in sdss.columns:
    nnans = np.sum(np.isnan(sdss[col]))
    if nnans > 0:
        print( f'Nans in {col}: {nnans}' )

for wsnr in ['w1snr', 'w2snr', 'w3snr', 'w4snr']:
    frac_missing = np.sum( sdss[wsnr] < 2 ) / len(sdss[wsnr])
    print('{:.2f}% of the obs in {} are non-detections'.format(100*frac_missing, wsnr[0:2]))
# Out:
# 0.01% of the obs in w1 are non-detections
# 1.11% of the obs in w2 are non-detections
# 34.22% of the obs in w3 are non-detections
# 64.98% of the obs in w4 are non-detections

# %% [markdown]
# Given that there are obs missing in each filter, with a substantial number missing in W3 and W4, we will create a new categorical variable for detection in each filter. We will also replace "upper limits" with -9.99 (do this in the cell below).
#
# (Alternative strategies that could prove worthwhile include: removing W3 and W4 as they are largely missing, imputing the missing values for non-detections, or removing individual sources with non-detections. This last choice would really cut the training set).

# %%
for filt in ['w1', 'w2', 'w3', 'w4']:
    det = np.ones(len(sdss)).astype(int)
    det[np.where(sdss['{}snr'.format(filt)] < 2)] = 0
    sdss['{}det'.format(filt)] = det
    mag = sdss['{}mpro'.format(filt)].values
    mag[det == 0] = -9.99
    sdss['{}mag'.format(filt)] = mag

# %%
sdss
# Out:
#                 specObjID         z  psfMag_u  psfMag_g  psfMag_r  psfMag_i  \
# 0      299567742770505728  0.071414  20.88291  19.23907  18.56170  18.09715
# 1      299568017178650624  0.071380  20.88291  19.23907  18.56170  18.09715
# 2      299566643258877952  0.088173  20.84844  18.96040  18.08027  17.62953
# 3      299569116690278400  0.088161  20.84844  18.96040  18.08027  17.62953
# 4      299568292056557568  0.066539  21.28256  19.61427  18.98529  18.52956
# ...                   ...       ...       ...       ...       ...       ...
# 49995  427910439263823872  0.122827  22.04694  19.90851  18.95757  18.66708
# 49996  427913462920800256  0.259755  21.49931  20.45282  19.28250  18.89629
# 49997  427892022444058624 -0.000071  23.55219  21.35737  19.77218  18.17955
# 49998  427901368292894720 -0.000028  23.72416  24.05965  22.91600  19.86693
# 49999  427902467804522496  0.241652  21.18222  20.29527  19.72853  19.50787
#
#        psfMag_z  modelMag_u  modelMag_g  modelMag_r  ...  ext  ps  w1det  \
# 0      17.76469    19.62189    18.03702    17.31203  ...    1   0      1
# 1      17.76469    19.62189    18.03702    17.31203  ...    1   0      1
# 2      17.31857    20.18508    18.26120    17.33220  ...    1   0      1
# 3      17.31857    20.18508    18.26120    17.33220  ...    1   0      1
# 4      18.26322    20.18081    18.47435    17.74616  ...    1   0      1
# ...         ...         ...         ...         ...  ...  ...  ..    ...
# 49995  18.18741    20.41257    18.49640    17.49542  ...    1   0      1
# 49996  18.41247    20.96373    19.73372    18.45652  ...    1   0      1
# 49997  17.30377    23.69296    21.35464    19.76457  ...    0   1      1
# 49998  18.24050    23.62215    24.03528    22.90985  ...    0   1      1
# 49999  19.08041    20.62539    19.67341    18.93440  ...    1   0      1
#
#         w1mag  w2det   w2mag  w3det   w3mag  w4det  w4mag
# 0      14.395      1  14.236      1  11.029      0 -9.990
# 1      14.395      1  14.236      1  11.029      0 -9.990
# 2      14.162      1  13.970      1  12.233      0 -9.990
# 3      14.162      1  13.970      1  12.233      0 -9.990
# 4      14.734      1  14.512      1  11.078      1  9.054
# ...       ...    ...     ...    ...     ...    ...    ...
# 49995  14.575      1  14.397      0  -9.990      0 -9.990
# 49996  14.745      1  14.481      0  -9.990      0 -9.990
# 49997  14.736      1  14.634      0  -9.990      0 -9.990
# 49998  14.893      1  14.675      1  11.931      0 -9.990
# 49999  15.449      1  14.786      1  10.709      1  8.771
#
# [50000 rows x 35 columns]

# %% [markdown]
# Now that we have dealt with missing and categorical data we can construct out machine learning model. We will use a $k$ nearest neighbors regression model to determine how well we can measure photometric redshifts.
#
# The `sdss` dataframe now includes far more columns than are necessary for the model. Should any of these be excluded from the fitting?

# %% [markdown]
# **Problem 4d**
#
# Build a `scikit-learn` appropriate `X` and `y` array for the features and labels (i.e. redshifts) of the photo-z training set.

# %%
feat_list = list( sdss.columns )
label_name = 'z'

feat_list.remove(label_name)

X = sdss[feat_list]
y = sdss[label_name]

X = X.drop( columns = ['specObjID'])

X
# Out:
#        psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  modelMag_u  \
# 0      20.88291  19.23907  18.56170  18.09715  17.76469    19.62189
# 1      20.88291  19.23907  18.56170  18.09715  17.76469    19.62189
# 2      20.84844  18.96040  18.08027  17.62953  17.31857    20.18508
# 3      20.84844  18.96040  18.08027  17.62953  17.31857    20.18508
# 4      21.28256  19.61427  18.98529  18.52956  18.26322    20.18081
# ...         ...       ...       ...       ...       ...         ...
# 49995  22.04694  19.90851  18.95757  18.66708  18.18741    20.41257
# 49996  21.49931  20.45282  19.28250  18.89629  18.41247    20.96373
# 49997  23.55219  21.35737  19.77218  18.17955  17.30377    23.69296
# 49998  23.72416  24.05965  22.91600  19.86693  18.24050    23.62215
# 49999  21.18222  20.29527  19.72853  19.50787  19.08041    20.62539
#
#        modelMag_g  modelMag_r  modelMag_i  modelMag_z  ...  ext  ps  w1det  \
# 0        18.03702    17.31203    16.88143    16.62089  ...    1   0      1
# 1        18.03702    17.31203    16.88143    16.62089  ...    1   0      1
# 2        18.26120    17.33220    16.90263    16.59397  ...    1   0      1
# 3        18.26120    17.33220    16.90263    16.59397  ...    1   0      1
# 4        18.47435    17.74616    17.33991    17.07917  ...    1   0      1
# ...           ...         ...         ...         ...  ...  ...  ..    ...
# 49995    18.49640    17.49542    17.05273    16.69769  ...    1   0      1
# 49996    19.73372    18.45652    17.95443    17.55054  ...    1   0      1
# 49997    21.35464    19.76457    18.17700    17.29953  ...    0   1      1
# 49998    24.03528    22.90985    19.86379    18.24099  ...    0   1      1
# 49999    19.67341    18.93440    18.54274    18.28055  ...    1   0      1
#
#         w1mag  w2det   w2mag  w3det   w3mag  w4det  w4mag
# 0      14.395      1  14.236      1  11.029      0 -9.990
# 1      14.395      1  14.236      1  11.029      0 -9.990
# 2      14.162      1  13.970      1  12.233      0 -9.990
# 3      14.162      1  13.970      1  12.233      0 -9.990
# 4      14.734      1  14.512      1  11.078      1  9.054
# ...       ...    ...     ...    ...     ...    ...    ...
# 49995  14.575      1  14.397      0  -9.990      0 -9.990
# 49996  14.745      1  14.481      0  -9.990      0 -9.990
# 49997  14.736      1  14.634      0  -9.990      0 -9.990
# 49998  14.893      1  14.675      1  11.931      0 -9.990
# 49999  15.449      1  14.786      1  10.709      1  8.771
#
# [50000 rows x 33 columns]

# %% [markdown]
# **Problem 4e**
#
# Estimate the RMSE for a [`KNeighborsRegression`](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html) via 10 fold CV.
#
# *Hint* - use [`cross_val_predict`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_predict.html) in this case so you can plot $z_\mathrm{SDSS}$ vs. $z_\mathrm{kNN}$.
#
# *Hint 2* - make the plot in a separate cell so you can adjust it without needing to re-run the CV.

# %%
# cross validation goes here
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_squared_error

knn_reg = KNeighborsRegressor(n_neighbors=10)
knn_reg.fit(X, y)

y_preds = cross_val_predict( knn_reg, X, y)
print('The RMSE = {}'.format(np.sqrt(mean_squared_error(y,y_preds))))
# Out:
# The RMSE = 0.23826340053122325

# %%
# plotting goes here

fig, ax = plt.subplots(figsize=(7,7))
ax.scatter( y, y_preds ) 
ax.plot([0,6],[0,6], 'Crimson')
ax.set_xlabel('z_SDSS')
ax.set_ylabel('z_kNN')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# If you made a plot of redshift vs. predictions, you likely saw that there are many sources that are far from the 1 to 1 line. These are called catastrophic outliers, and they are a serious problem for science programs that rely on photometric redshifts.

# %% [markdown]
# **Problem 4f**
#
# Write a function that takes input arrays `ground_truth` and `predictions` and determines the fraction of the dataset that is catastrophic outliers. For today's purposes we will say a catastrophic outlier is one where the prediction differs by 20%.

# %%
def catastrophic_fraction(ground_truth, predictions, threshold=0.2):
    '''Function to calculate fraction of predictions that are catastrophic outliers
    
    Parameter
    ---------
    ground_truth : array-like
        Correct labels for the model sources
    
    predictions : array-like
        Predictions for the model sources
    
    threshold : float (optional, default=0.2)
        The threshold to determine if a "miss" is catastrophic or not
    
    Returns
    -------
    oh_nos : float
        Fractional number of catastrophic outliers
    '''
    oh_nos = np.sum( np.abs(ground_truth-predictions)/ground_truth > 0.2 ) / len(ground_truth)

    return oh_nos

# %% [markdown]
# **Problem 4g**
#
# How many catastrophic outliers did your previous predictions have?

# %%
catastrophic_fraction( np.array(y), y_preds )
# Out:
# /var/folders/j2/tlw62j517hb6ch7m280c_66h0000gn/T/ipykernel_8664/2711109254.py:20: RuntimeWarning: divide by zero encountered in true_divide
#   oh_nos = np.sum( np.abs(ground_truth-predictions)/ground_truth > 0.2 ) / len(ground_truth)
# 0.47022

# %% [markdown]
# Earlier we saw that the performance of a kNN model greatly improves with feature scaling.
#
# **Problem 4h**
#
# Use a MinMax scaler to scale the features, performs 10 fold cross-validation, and estimate the catastrophic outlier fraction.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
Xminmax = scaler.transform(X)

knn_reg = KNeighborsRegressor(n_neighbors=7)
y_preds = cross_val_predict( knn_reg, X, y)
print('The RMSE = {}'.format(np.sqrt(mean_squared_error(y,y_preds))))
print('{} are catastrophic'.format(catastrophic_fraction(y, y_preds)))
# Out:
# The RMSE = 0.24127507786967387
# 0.47418 are catastrophic

# %%
# plotting goes here

fig, ax = plt.subplots()
ax.scatter( y, y_preds)
ax.plot([0,6],[0,6], 'Crimson')
ax.set_xlabel('z_SDSS')
ax.set_ylabel('z_kNN')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# The MinMax scaler didn't help at all!
#
# Perhaps we need a different kind of wrangling for this data set - feature engineering. (For example, does it make sense to include `extinction` as a feature, or should we instead combine the extinction with the observed magnitudes to get extinction corrected brightness measurements?)
#
# Finally - we close with a machine learning question, not a data wrangling question. Does it actually make sense to use a kNN model for datasets that have categorical features?

# %% [markdown]
# **Problem 4i**
#
# Build a better machine learning model, possibly with the use of different features, to improve the model classification performance.
#
# *Hint* - there was a hint about this in yesterday's lecture.

# %%
from sklearn.ensemble import RandomForestRegressor

# complete
# complete
# complete
# complete

# %%
# plotting goes here

fig, ax = plt.subplots(figsize=(8,8))
ax.scatter( # complete
ax.plot([0,6],[0,6], 'Crimson')
ax.set_xlim(-0.1,4)
ax.set_ylim(-0.1,4)
ax.set_xlabel('z_SDSS')
ax.set_ylabel('z_kNN')
