# %% [markdown]
# # Exercises
#
# ## Search algorithms
#
# Let's look at two different kinds of search algorithms: linear and binary.

# %%
def linear_search(items, desired_item):
    for position, item in enumerate(items):
        if item == desired_item:
            return position

    raise ValueError("%s was not found in the list." % desired_item)

# %%
def binary_search(arr, x):
    low = 0
    high = len(arr) - 1
    mid = 0
 
    while low <= high:
 
        mid = (high + low) // 2
 
        # If x is greater, ignore left half
        if arr[mid] < x:
            low = mid + 1
 
        # If x is smaller, ignore right half
        elif arr[mid] > x:
            high = mid - 1
 
        # means x is present at mid
        else:
            return mid
 
    # If we reach here, then the element was not present
    return -1

# %% [markdown]
# Create a Python list with several thousand of random elements. Append the element `10` and shuffle the list.

# %%
import numpy as np

random_ints = list(np.random.randint(0,500, size=10_000))

random_ints.append(10)

random_ints
# Out:
# [116,
#  248,
#  440,
#  198,
#  372,
#  251,
#  214,
#  22,
#  409,
#  55,
#  182,
#  464,
#  90,
#  370,
#  189,
#  176,
#  36,
#  332,
#  498,
#  103,
#  327,
#  109,
#  183,
#  479,
#  184,
#  71,
#  401,
#  53,
#  291,
#  258,
#  463,
#  211,
#  177,
#  359,
#  150,
#  422,
#  471,
#  198,
#  345,
#  366,
#  204,
#  131,
#  287,
#  321,
#  115,
#  85,
#  26,
#  232,
#  163,
#  223,
#  448,
#  28,
#  19,
#  97,
#  327,
#  200,
#  477,
#  66,
#  257,
#  379,
#  11,
#  6,
#  213,
#  213,
#  310,
#  397,
#  158,
#  277,
#  200,
#  36,
#  5,
#  3,
#  280,
#  263,
#  280,
#  77,
#  5,
#  190,
#  44,
#  272,
#  341,
#  440,
#  489,
#  22,
#  264,
#  293,
#  395,
#  152,
#  158,
#  374,
#  50,
#  122,
#  211,
#  164,
#  129,
#  393,
#  165,
#  312,
#  99,
#  354,
#  425,
#  240,
#  23,
#  180,
#  485,
#  97,
#  64,
#  328,
#  21,
#  444,
#  18,
#  16,
#  488,
#  53,
#  268,
#  80,
#  135,
#  428,
#  454,
#  188,
#  3,
#  308,
#  337,
#  229,
#  28,
#  275,
#  289,
#  85,
#  166,
#  458,
#  453,
#  306,
#  22,
#  1,
#  467,
#  298,
#  25,
#  36,
#  46,
#  37,
#  181,
#  138,
#  446,
#  72,
#  46,
#  143,
#  70,
#  267,
#  259,
#  83,
#  377,
#  468,
#  12,
#  404,
#  496,
#  338,
#  481,
#  374,
#  24,
#  242,
#  247,
#  487,
#  223,
#  303,
#  78,
#  475,
#  399,
#  161,
#  288,
#  249,
#  59,
#  10,
#  413,
#  39,
#  184,
#  373,
#  54,
#  483,
#  216,
#  57,
#  457,
#  93,
#  369,
#  205,
#  335,
#  241,
#  12,
#  449,
#  389,
#  386,
#  494,
#  473,
#  334,
#  79,
#  162,
#  352,
#  334,
#  216,
#  23,
#  27,
#  86,
#  102,
#  64,
#  35,
#  356,
#  146,
#  332,
#  73,
#  418,
#  467,
#  36,
#  397,
#  279,
#  105,
#  129,
#  309,
#  114,
#  224,
#  393,
#  179,
#  53,
#  196,
#  460,
#  224,
#  468,
#  55,
#  38,
#  54,
#  155,
#  101,
#  193,
#  156,
#  362,
#  321,
#  275,
#  60,
#  355,
#  239,
#  138,
#  79,
#  144,
#  474,
#  415,
#  423,
#  146,
#  421,
#  101,
#  459,
#  431,
#  283,
#  376,
#  164,
#  262,
#  424,
#  163,
#  270,
#  225,
#  401,
#  433,
#  49,
#  41,
#  15,
#  323,
#  99,
#  120,
#  367,
#  422,
#  57,
#  279,
#  378,
#  413,
#  190,
#  494,
#  391,
#  436,
#  417,
#  271,
#  115,
#  210,
#  315,
#  12,
#  221,
#  188,
#  101,
#  24,
#  373,
#  446,
#  342,
#  47,
#  169,
#  144,
#  350,
#  0,
#  95,
#  427,
#  38,
#  357,
#  113,
#  78,
#  175,
#  116,
#  15,
#  190,
#  360,
#  298,
#  23,
#  457,
#  289,
#  417,
#  350,
#  450,
#  73,
#  132,
#  444,
#  198,
#  362,
#  341,
#  384,
#  329,
#  296,
#  242,
#  57,
#  368,
#  263,
#  21,
#  236,
#  377,
#  477,
#  347,
#  366,
#  211,
#  18,
#  161,
#  64,
#  64,
#  436,
#  222,
#  233,
#  322,
#  294,
#  222,
#  117,
#  341,
#  457,
#  439,
#  457,
#  85,
#  4,
#  385,
#  80,
#  100,
#  131,
#  205,
#  105,
#  430,
#  277,
#  162,
#  478,
#  140,
#  383,
#  454,
#  110,
#  434,
#  319,
#  397,
#  417,
#  143,
#  300,
#  320,
#  286,
#  217,
#  164,
#  185,
#  65,
#  154,
#  113,
#  30,
#  150,
#  313,
#  382,
#  387,
#  312,
#  165,
#  90,
#  73,
#  333,
#  253,
#  6,
#  56,
#  370,
#  308,
#  251,
#  346,
#  103,
#  483,
#  420,
#  378,
#  137,
#  34,
#  122,
#  310,
#  248,
#  356,
#  48,
#  320,
#  119,
#  417,
#  392,
#  423,
#  279,
#  250,
#  237,
#  441,
#  227,
#  202,
#  462,
#  125,
#  301,
#  111,
#  336,
#  84,
#  182,
#  42,
#  127,
#  226,
#  221,
#  149,
#  249,
#  170,
#  459,
#  315,
#  492,
#  152,
#  265,
#  207,
#  110,
#  207,
#  386,
#  359,
#  27,
#  231,
#  28,
#  235,
#  421,
#  462,
#  414,
#  352,
#  461,
#  27,
#  172,
#  258,
#  346,
#  380,
#  248,
#  106,
#  159,
#  354,
#  374,
#  307,
#  379,
#  292,
#  70,
#  73,
#  418,
#  301,
#  142,
#  350,
#  452,
#  383,
#  418,
#  425,
#  418,
#  438,
#  25,
#  403,
#  350,
#  159,
#  484,
#  8,
#  72,
#  157,
#  15,
#  226,
#  163,
#  216,
#  395,
#  469,
#  36,
#  119,
#  455,
#  307,
#  216,
#  181,
#  182,
#  238,
#  298,
#  183,
#  385,
#  456,
#  12,
#  430,
#  334,
#  226,
#  74,
#  122,
#  452,
#  107,
#  395,
#  96,
#  465,
#  73,
#  456,
#  252,
#  381,
#  426,
#  181,
#  125,
#  385,
#  244,
#  368,
#  387,
#  190,
#  245,
#  45,
#  473,
#  114,
#  213,
#  422,
#  472,
#  45,
#  49,
#  115,
#  295,
#  3,
#  58,
#  240,
#  31,
#  253,
#  454,
#  417,
#  313,
#  311,
#  433,
#  490,
#  103,
#  5,
#  467,
#  319,
#  485,
#  494,
#  85,
#  68,
#  244,
#  82,
#  101,
#  262,
#  418,
#  279,
#  375,
#  272,
#  184,
#  206,
#  142,
#  459,
#  65,
#  170,
#  119,
#  112,
#  117,
#  360,
#  193,
#  186,
#  204,
#  468,
#  68,
#  229,
#  195,
#  125,
#  411,
#  374,
#  9,
#  113,
#  207,
#  330,
#  293,
#  183,
#  361,
#  57,
#  112,
#  230,
#  413,
#  410,
#  288,
#  331,
#  283,
#  391,
#  2,
#  337,
#  69,
#  498,
#  340,
#  253,
#  438,
#  106,
#  192,
#  209,
#  361,
#  393,
#  409,
#  378,
#  102,
#  170,
#  367,
#  485,
#  363,
#  207,
#  247,
#  76,
#  340,
#  76,
#  264,
#  356,
#  358,
#  307,
#  343,
#  168,
#  146,
#  368,
#  479,
#  202,
#  472,
#  206,
#  59,
#  194,
#  219,
#  236,
#  267,
#  26,
#  435,
#  162,
#  353,
#  197,
#  67,
#  366,
#  265,
#  430,
#  187,
#  348,
#  134,
#  253,
#  181,
#  33,
#  236,
#  140,
#  331,
#  434,
#  159,
#  161,
#  231,
#  250,
#  145,
#  297,
#  97,
#  245,
#  483,
#  203,
#  84,
#  46,
#  201,
#  85,
#  234,
#  447,
#  441,
#  350,
#  133,
#  80,
#  12,
#  80,
#  333,
#  357,
#  127,
#  293,
#  308,
#  46,
#  0,
#  369,
#  299,
#  180,
#  298,
#  495,
#  134,
#  287,
#  131,
#  293,
#  127,
#  237,
#  242,
#  111,
#  332,
#  223,
#  288,
#  79,
#  291,
#  193,
#  302,
#  474,
#  125,
#  450,
#  400,
#  366,
#  362,
#  253,
#  1,
#  419,
#  374,
#  384,
#  467,
#  444,
#  370,
#  107,
#  38,
#  293,
#  472,
#  367,
#  74,
#  298,
#  122,
#  434,
#  151,
#  294,
#  377,
#  319,
#  4,
#  210,
#  379,
#  145,
#  127,
#  442,
#  453,
#  71,
#  2,
#  31,
#  167,
#  53,
#  305,
#  194,
#  384,
#  441,
#  306,
#  150,
#  137,
#  169,
#  60,
#  277,
#  286,
#  420,
#  39,
#  382,
#  163,
#  69,
#  76,
#  233,
#  24,
#  94,
#  247,
#  171,
#  59,
#  477,
#  372,
#  113,
#  91,
#  389,
#  56,
#  246,
#  311,
#  348,
#  55,
#  305,
#  101,
#  25,
#  214,
#  346,
#  490,
#  440,
#  49,
#  276,
#  271,
#  276,
#  5,
#  73,
#  196,
#  135,
#  466,
#  195,
#  240,
#  494,
#  498,
#  271,
#  144,
#  175,
#  484,
#  45,
#  102,
#  33,
#  287,
#  49,
#  164,
#  309,
#  429,
#  53,
#  428,
#  226,
#  36,
#  351,
#  320,
#  93,
#  121,
#  456,
#  402,
#  218,
#  345,
#  424,
#  59,
#  244,
#  458,
#  32,
#  291,
#  136,
#  81,
#  238,
#  326,
#  24,
#  201,
#  80,
#  189,
#  32,
#  211,
#  31,
#  341,
#  435,
#  263,
#  43,
#  467,
#  139,
#  171,
#  184,
#  429,
#  121,
#  192,
#  476,
#  19,
#  96,
#  154,
#  405,
#  491,
#  445,
#  451,
#  499,
#  119,
#  377,
#  499,
#  182,
#  164,
#  95,
#  172,
#  298,
#  463,
#  97,
#  372,
#  351,
#  413,
#  174,
#  364,
#  29,
#  226,
#  367,
#  286,
#  419,
#  222,
#  328,
#  337,
#  484,
#  489,
#  376,
#  367,
#  302,
#  118,
#  65,
#  325,
#  297,
#  471,
#  449,
#  351,
#  363,
#  434,
#  76,
#  37,
#  69,
#  302,
#  362,
#  316,
#  338,
#  496,
#  221,
#  9,
#  303,
#  329,
#  25,
#  445,
#  69,
#  422,
#  371,
#  117,
#  155,
#  295,
#  411,
#  300,
#  389,
#  177,
#  484,
#  98,
#  184,
#  400,
#  9,
#  372,
#  315,
#  341,
#  249,
#  102,
#  480,
#  119,
#  278,
#  33,
#  270,
#  111,
#  265,
#  93,
#  276,
#  139,
#  216,
#  23,
#  415,
#  50,
#  321,
#  383,
#  298,
#  91,
#  204,
#  192,
#  129,
#  315,
#  134,
#  136,
#  238,
#  469,
#  241,
#  427,
#  376,
#  281,
#  464,
#  234,
#  380,
#  219,
#  390,
#  259,
#  241,
#  273,
#  0,
#  455,
#  463,
#  90,
#  139,
#  69,
#  448,
#  413,
#  281,
#  411,
#  111,
#  24,
#  185,
#  363,
#  336,
#  30,
#  30,
#  339,
#  50,
#  43,
#  291,
#  129,
#  181,
#  385,
#  139,
#  257,
#  490,
#  294,
#  291,
#  449,
#  234,
#  58,
#  403,
#  ...]

# %% [markdown]
# Create an optmized array either with Numpy, Pandas, or other library you want to test that contains the same amount of random elements of the previous array

# %% [markdown]
# Perform a simple bench mark using both arrays and both search methods. What is faster? Does it corresponds with your intuition?

# %%
# %%timeit
ls = linear_search( random_ints, 10 )
# Out:
# 17.9 µs ± 583 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit

random_ints.sort()
bs = binary_search(random_ints, 10)
# Out:
# 164 µs ± 5.14 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
ls = linear_search( random_ints, 10 )
bs = binary_search(, 10)

# %% [markdown]
# Print the index where the element was found in each one of the structures.

# %%
ls, bs
# Out:
# (531, -1)

# %% [markdown]
# Add a new element to the data structures you just created. Append the element `20`, but this time don't suffle the structures. If you perform the same benchmarks what do you observe?

# %%
random_ints.append(20)

lss = linear_search( random_ints, 20 )
bss = binary_search(random_ints.sort(), 20)

lss, bss
# Out:
# (665, -1)

# %%
# %%timeit
lss = linear_search( random_ints, 20 )
# Out:
# 71.2 µs ± 2.88 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
bss = binary_search(random_ints.sort(), 20)
# Out:
# 4.03 µs ± 147 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# Can you infer what's the Big O complexity of the algorithms?

# %% [markdown]
# *It seems that linear is linear and binary may be O(1)?*

# %% [markdown]
# What are the circunstances in which you should use one or the other kind of search? What are the cases and the specific kinds of arrays in which each search makes the most sense to be used?

# %% [markdown]
# *In the linear search we can collect other information while looping through, while the binary search only finds the correct element.*

# %% [markdown]
# ## List comprehensions

# %% [markdown]
# Let's test the power of list comprehensions.

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
        "a": np.random.randn(1000),
        "b": np.random.randn(1000),
        "N": np.random.randint(100, 1000, (1000)),
        "x": "x",
    })
df
# Out:
#             a         b    N  x
# 0    0.160363 -1.027066  675  x
# 1    1.032984 -1.680710  950  x
# 2   -0.377946  0.800685  209  x
# 3    0.271383  0.644445  345  x
# 4    0.537304  0.785844  479  x
# ..        ...       ...  ... ..
# 995 -1.114295 -0.606032  158  x
# 996 -0.032966 -0.647988  394  x
# 997 -0.854240  1.608830  965  x
# 998  0.079976 -0.444217  736  x
# 999  0.275919  0.038994  890  x
#
# [1000 rows x 4 columns]

# %%
def f(x):
    return x * (x - 1)

def integrate_f(a, b, N):
    s = 0
    dx = (b - a) / N

    for i in range(int(N)):
        s += f(a + i * dx)

    return s * dx

# %% [markdown]
# Usind the data set and the `integrate_f` function above write a function that uses the `integrate_f` as a `for` loop and another one in the form of a `lambda`. Use `df.apply` to apply the results of your `lambda`.

# %%
# %%prun

dat = df[['a', 'b', 'N']].values
for i in range(len(df)):
    integrate_f(*dat[i])

# %%
# %%prun

df.apply( lambda args : integrate_f(*args[0:3]), axis=1 )

# %% [markdown]
# Now use the `timeit`, `prun -l N`(N is the number of lines you want to have displayed) and `snakevyz` to check the different processing times

# %% [markdown]
# ## Optimizing Python functions

# %% [markdown]
# Try to optmize the following function:

# %%
def vowel_count(str):
    # Initializing count variable to 0
    count = 0
      
    # Creating a set of vowels
    vowel = set("aeiouAEIOU")
      
    # Loop to traverse the alphabet
    # in the given string
    for alphabet in str:
      
        # If alphabet is present
        # in set vowel
        if alphabet in vowel:
            count = count + 1

# %% [markdown]
# Use this function as an input for your `vowel_count` function.

# %%
import random
import string


def random_char(y):
       return ''.join(random.choice(string.ascii_letters) for x in range(y))

# %% [markdown]
# Here's another function you can try:
#
# Before starting to code anything and thinking about the tools that were presented in this class, do you have an idea for which tool you could use to optimize the following function?

# %%
def steps_to(stair):
    if stair == 1:
        return 1
    elif stair == 2:
        return 2
    elif stair == 3:
        return 4
    else:
        return (steps_to(stair - 3)
                + steps_to(stair - 2)
                + steps_to(stair - 1))

# %% [markdown]
# ## Numba performance

# %% [markdown]
# Numba has to compile your function for the argument types given before it executes the machine code version of your function, this takes time. However, once the compilation has taken place Numba caches the machine code version of your function for the particular types of arguments presented. If it is called again the with same types, it can reuse the cached version instead of having to compile again.
#
# A really common mistake when measuring performance is to not account for the above behaviour and to time code once with a simple timer that includes the time taken to compile your function in the execution time.
#
# Using the `timeit` module is a way of avoiding this.

# %%
# !pip install numba

# %%
from numba import jit, njit

# %% [markdown]
# Use the following options to test the code in the next cell:
#
#     parallel = True - enable the automatic parallelization of the function.
#     parallel = True - enable the automatic parallelization of the function.
#
#     fastmath = True - enable fast-math behaviour for the function. (If true, fastmath enables the use of otherwise unsafe floating point transforms as described in the LLVM documentation.)
#
# These are arguments for the `jit` decorator we saw earlier in the examples.
#
# `njit` and `jit(nopython=True` are the same. This means that Numba tries to release the global interpreter lock inside the compiled function. The GIL will only be released if Numba can compile the function in nopython mode, otherwise a compilation warning will be printed.

# %%
def do_sum(A):
    acc = 0.
    # without fastmath, this loop must accumulate in strict order
    for x in A:
        acc += np.sqrt(x)
    return acc

def do_sum_fast(A):
    acc = 0.
    # with fastmath, the reduction can be vectorized as floating point
    # reassociation is permitted.
    for x in A:
        acc += np.sqrt(x)
    return acc

# %% [markdown]
# # Interacting with I/O

# %% [markdown]
# Let's compare some I/O flows.
#
# In the following cells the code to create a dataset using `h5py` was given to you.

# %%
# !pip install h5py

# %%
import h5py

array = np.random.random(size=(10))
h5f = h5py.File('data.h5', 'w')
h5f.create_dataset('dataset', data = array)

# %%
h5_loaded = h5f['dataset'][:]

# %%
for i in range(len(h5_loaded)):
    h5_loaded[i] = 1

# %% [markdown]
# Implement an equivalent dataset to this one, but this time using Python's CSV. If you want also give it a try using Pandas and Numpy.

# %% [markdown]
# Change the parameters in this function, things like the size of `np` array and the operation executed inside the `for` loop, maybe you want to add a transformation to each value of the dataset. Explore how performance changes.
